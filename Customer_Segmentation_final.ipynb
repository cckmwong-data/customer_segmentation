# %% [markdown]
# #**CUSTOMER SEGMENTATION USING K-PROTOTYPE**

# %% [markdown]
# ## **Problem Statement**
# With rising competition and evolving customer expectations, insurers leverage data-driven intelligence to understand customer behavior and tailor their offerings accordingly. Customer segmentation provides a structured way to group individuals with shared characteristics, enabling more efficient targeting and  marketing strategies.
#
# In this project, we perform customer segmentation using the K-Prototypes clustering algorithm, which effectively handles mixed numerical and categorical data such as demographics, income, spending behavior, and policy attributes. After identifying the underlying clusters, Gemini AI is employed to interpret each group’s defining traits and generate concise, meaningful segment names and descriptions. The resulting customer groups — Young Independent Starters, Affluent Independent Navigators and Loyal Established Households, offer the company actionable insights that support personalized marketing, retention strategies, and strategic product positioning.

# %% [markdown]
# ## **Workflow Summary**
#
# This is a project covering an automated end-to-end data pipeline which performs clustering, stores the output in a warehouse, and updates a live dashboard.
#
# 1. **Data Ingestion**: Collecting raw data from Google Sheets: [customers.csv](https://docs.google.com/spreadsheets/d/1bzB4VDQEQz0BIbyT2BCIvcE2rPSAlOcmeQuvMtuIFcI/export?format=csv), [sales.csv](https://docs.google.com/spreadsheets/d/1xrPtoy8R965CPSCS59_hcLP1cwzNcp7DJ2MOegZrsVA/export?format=csv), [products.csv](https://docs.google.com/spreadsheets/d/1HpCKgERS0F9qjHh3y0_GZ988JjX4vtKBX5rIksCgB5I/gviz/tq?tqx=out:csv&gid=0)
#
# 2. **Data Processing (Extract-Transform-Load ETL)**
# *   Data cleaning (e.g. checking any missing values or duplicates)
# *   Data wrangling and feature engineering to ensure the data is in the right format for K-Prototype clustering
# *   K-Prototypes clustering
# *   Segment labeling and description generated by Gemini 2.5 Flash
# *   Loading the updated customers, sales and products tables to Google BigQuery
# *   Automation of the above process via GitHub Actions (daily at 10PM UK time)
# ![github_action.png](data:image/png;base64,...)
# 3. **Data Warehousing**: Processed model outputs were stored as tables in BigQuery for reporting and analysis, alongside views generated from SQL queries.
#
# ![bq.jpg](data:image/jpeg;base64,...)
#
# 4. **Business Intelligence**: A [live dashboard](https://app.powerbi.com/view?r=eyJrIjoiNThiYjk5ZWQtZDcwYy00YWFhLWFlNjItNGI1OGNiNDE2Y2E1IiwidCI6IjZjMWQ0MTUyLTM5ZDAtNDRjYS04OGQ5LWI4ZDZkZGNhMDcwOCIsImMiOjEwfQ%3D%3D) in Microsoft Power BI shows an analysis of customer and sales data the company. Data is scheduled for an automatic update on a daily basis at 11PM UK time.

# %% [markdown]
# ##**ETL Pipeline of the Whole Project**
#
# ---
# ![ETL_pipeline.png](data:image/png;base64,...)

# %% [markdown]
# # (1) Import Libraries

# %%
# !pip install kmodes # install kmodes for KPrototypes algorithm
# Out:
# Requirement already satisfied: kmodes in /usr/local/lib/python3.12/dist-packages (0.12.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.12/dist-packages (from kmodes) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from kmodes) (1.6.1)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.12/dist-packages (from kmodes) (1.16.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from kmodes) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.6.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, normalize, OneHotEncoder
from kmodes.kprototypes import KPrototypes
from sklearn.decomposition import PCA
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from pandas_gbq import read_gbq

# %%
import random

# Fix global seeds
np.random.seed(42)
random.seed(42)

# %%
import os

# read environment variable when running Github Action where we defined RUN_GENAI as false
# not run Gen AI block if checked RUN_GENAI is false
RUN_GENAI = os.getenv("RUN_GENAI", "false").lower() == "true"
print("RUN_GENAI =", RUN_GENAI)
# Out:
# RUN_GENAI = False

# %% [markdown]
# # (2) Import Dataset
# First, we collect customer, sales and product data from the three spreadsheets stored in Google Sheet, namely 1) customers.csv, 2) sales.csv and 3) products.csv, respectively.

# %%
# Extract the customer data from a csv file in Google Sheet
df_customers = pd.read_csv('https://docs.google.com/spreadsheets/d/1bzB4VDQEQz0BIbyT2BCIvcE2rPSAlOcmeQuvMtuIFcI/export?format=csv')
df_customers
# Out:
#      Customer_ID  Age  Gender                City Marital_Status  \
# 0        HL00001   41    Male           Sheffield         Single
# 1        HL00002   50  Female          Manchester        Married
# 2        HL00003   33  Female              London       Divorced
# 3        HL00004   43    Male           Edinburgh        Married
# 4        HL00005   36    Male           Liverpool      Separated
# ...          ...  ...     ...                 ...            ...
# 3441     HL03442   42    Male             Bristol         Single
# 3442     HL03443   18    Male               Leeds       Divorced
# 3443     HL03444   34  Female              London       Divorced
# 3444     HL03445   54  Female             Belfast        Married
# 3445     HL03446   25  Female  Kingston upon Hull        Widowed
#
#               Education    Occupation      Income Preferred_Language  \
# 0      Associate Degree        Lawyer   18719.316             French
# 1             Doctorate  Entrepreneur   59456.052            English
# 2             Doctorate        Lawyer   61078.656             Arabic
# 3       Master's Degree        Lawyer   39333.528            English
# 4     Bachelor's Degree         Nurse   25995.516            English
# ...                 ...           ...         ...                ...
# 3441    Master's Degree       Manager   48832.356            English
# 3442   Associate Degree        Doctor  127478.040            English
# 3443          Doctorate  Entrepreneur   97274.124            Chinese
# 3444  Bachelor's Degree       Manager   66348.840            English
# 3445  Bachelor's Degree       Manager   60926.220            English
#
#       Preferred_Channel Preferred_Time
# 0                 Email      Afternoon
# 1                 Email      Afternoon
# 2                 Email        Morning
# 3                 Email        Evening
# 4                  Mail        Evening
# ...                 ...            ...
# 3441              Email        Anytime
# 3442              Email      Afternoon
# 3443  In-Person Meeting        Morning
# 3444              Phone        Anytime
# 3445              Email        Morning
#
# [3446 rows x 11 columns]

# %%
# Extract the sales data from a csv file in Google Sheet
df_sales = pd.read_csv('https://docs.google.com/spreadsheets/d/1xrPtoy8R965CPSCS59_hcLP1cwzNcp7DJ2MOegZrsVA/export?format=csv')
df_sales
# Out:
#      Policy_ID Customer_ID Product_ID Purchase_Date      Premium      Coverage
# 0      P000008     HL00008  POL200008      5/4/2022   861.832800   97928.79508
# 1      P000010     HL00010  POL200016     3/17/2022  1294.144416  100724.49880
# 2      P000015     HL00015  POL200017     5/19/2022  2470.369199  102937.51920
# 3      P000019     HL00019  POL200018      8/3/2022  2032.112144   98439.34626
# 4      P000022     HL00022  POL200015     5/24/2023  1156.180369  101259.37510
# ...        ...         ...        ...           ...          ...           ...
# 3459   P003458     HL03367  POL200009    22/01/2022  5375.637343  519777.85190
# 3460   P003459     HL03367  POL200001    16/09/2021  4798.328801  336051.20600
# 3461   P003462     HL00347  POL200001     6/26/2011  5465.828597  382502.92070
# 3462   P003463     HL00347  POL200016     6/11/2012  5015.488343  396869.88540
# 3463   P003464     HL00347  POL200015      7/2/2013  4713.002623  389222.51350
#
# [3464 rows x 6 columns]

# %%
# Extract the products data from a csv file in Google Sheet
df_products = pd.read_csv('https://docs.google.com/spreadsheets/d/1HpCKgERS0F9qjHh3y0_GZ988JjX4vtKBX5rIksCgB5I/gviz/tq?tqx=out:csv&gid=0')
df_products
# Out:
#    Product_ID           Product_Name Product_Type    Category
# 0   POL200000        WellBeing Cover       Health       Group
# 1   POL200001             MediAssist       Health       Group
# 2   POL200002        FamilyLife Plus         Life       Group
# 3   POL200003             LifeShield         Life       Group
# 4   POL200004           SecureLegacy         Life       Group
# 5   POL200005              DriveSure         Auto       Group
# 6   POL200006            TradeSecure     Property    Business
# 7   POL200007            AssetShield     Property    Business
# 8   POL200008          OfficeProtect     Property    Business
# 9   POL200009            MotorShield         Auto    Business
# 10  POL200010            TruePromise         Life  Individual
# 11  POL200011           HealthBridge       Health  Individual
# 12  POL200012            PrimeHealth       Health  Individual
# 13  POL200013         EverGuard Life         Life  Individual
# 14  POL200014        QuickCover Auto         Auto  Individual
# 15  POL200015       VitalCare Family       Health      Family
# 16  POL200016     TruePromise Family         Life      Family
# 17  POL200017      LifeShield Family         Life      Family
# 18  POL200018  SuperGold Life Family         Life      Family

# %% [markdown]
# # (3) Data Cleaning
# This section performs an initial exploratory check on the three datasets — customers, sales, and products — to understand their structure and data quality. We inspect the columns, data types, and non-null counts for each dataset, ensuring that all expected fields are present and correctly formatted. Then we check for missing values and any duplicate rows. This process provides a quick overview of the data completeness and consistency before proceeding to further preprocessing or analysis.

# %%
# Check the columns and datatypes of customers data
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3446 entries, 0 to 3445
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         3446 non-null   object
#  1   Age                 3446 non-null   int64
#  2   Gender              3446 non-null   object
#  3   City                3446 non-null   object
#  4   Marital_Status      3446 non-null   object
#  5   Education           3446 non-null   object
#  6   Occupation          3446 non-null   object
#  7   Income              3446 non-null   float64
#  8   Preferred_Language  3446 non-null   object
#  9   Preferred_Channel   3446 non-null   object
#  10  Preferred_Time      3446 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 296.3+ KB

# %%
# Check the columns and datatypes of sales data
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3464 entries, 0 to 3463
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Policy_ID      3464 non-null   object
#  1   Customer_ID    3464 non-null   object
#  2   Product_ID     3464 non-null   object
#  3   Purchase_Date  3464 non-null   object
#  4   Premium        3464 non-null   float64
#  5   Coverage       3464 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 162.5+ KB

# %%
# Check the columns and datatypes of products data
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_ID    19 non-null     object
#  1   Product_Name  19 non-null     object
#  2   Product_Type  19 non-null     object
#  3   Category      19 non-null     object
# dtypes: object(4)
# memory usage: 740.0+ bytes

# %%
# Check for missing values for customers data
df_customers.isnull().sum()
# Out:
# Customer_ID           0
# Age                   0
# Gender                0
# City                  0
# Marital_Status        0
# Education             0
# Occupation            0
# Income                0
# Preferred_Language    0
# Preferred_Channel     0
# Preferred_Time        0
# dtype: int64

# %%
# Check for missing values for sales data
df_sales.isnull().sum()
# Out:
# Policy_ID        0
# Customer_ID      0
# Product_ID       0
# Purchase_Date    0
# Premium          0
# Coverage         0
# dtype: int64

# %%
# Check for missing values for products data
df_products.isnull().sum()
# Out:
# Product_ID      0
# Product_Name    0
# Product_Type    0
# Category        0
# dtype: int64

# %%
# Check if any duplicated rows
df_customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check if any duplicated rows
df_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check if any duplicated rows
df_products.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # (4) Data Wraggling and Visualization
# We further derive key metrics from the existing data, including customer loyalty (represented by the *Tenure_Years* column) and insurer profitability (captured through the *Premium_to_Coverage* ratio). These metrics provide insight into how long customers have been with the company and how much value they generate relative to their coverage. After computing these measures, we explored the distribution of both categorical and numerical variables to better understand customer demographics, purchasing behavior, and overall trends within the dataset.

# %%
# Find the loyalty of the customers by calculating the number of years the customers purchased the policy

# Convert 'Purchase_History' to pandas datetime format
df_sales['Purchase_Date'] = pd.to_datetime(df_sales['Purchase_Date'], format='mixed')

# Get today's date as a pandas Timestamp
today = pd.Timestamp.today()

# Convert 'Purchase_History' to individual timestamps before subtracting
df_sales['Tenure_Years'] = (today - df_sales['Purchase_Date'].astype('datetime64[ns]')).dt.days / 365

df_sales['Tenure_Years'] = df_sales['Tenure_Years'].round(2)

# %%
# Calculate premium to coverage ratio which shows the profitability for insurance company
# Higher the ratio, higher the amount customers willing to pay their premiums
# relative to the amount of coverage they are receiving

df_sales['Premium_to_Coverage'] = df_sales['Premium']/ df_sales['Coverage']*100
df_sales
# Out:
#      Policy_ID Customer_ID Product_ID Purchase_Date      Premium  \
# 0      P000008     HL00008  POL200008    2022-05-04   861.832800
# 1      P000010     HL00010  POL200016    2022-03-17  1294.144416
# 2      P000015     HL00015  POL200017    2022-05-19  2470.369199
# 3      P000019     HL00019  POL200018    2022-08-03  2032.112144
# 4      P000022     HL00022  POL200015    2023-05-24  1156.180369
# ...        ...         ...        ...           ...          ...
# 3459   P003458     HL03367  POL200009    2022-01-22  5375.637343
# 3460   P003459     HL03367  POL200001    2021-09-16  4798.328801
# 3461   P003462     HL00347  POL200001    2011-06-26  5465.828597
# 3462   P003463     HL00347  POL200016    2012-06-11  5015.488343
# 3463   P003464     HL00347  POL200015    2013-07-02  4713.002623
#
#           Coverage  Tenure_Years  Premium_to_Coverage
# 0      97928.79508          3.62             0.880061
# 1     100724.49880          3.75             1.284836
# 2     102937.51920          3.58             2.399872
# 3      98439.34626          3.37             2.064329
# 4     101259.37510          2.56             1.141801
# ...            ...           ...                  ...
# 3459  519777.85190          3.90             1.034218
# 3460  336051.20600          4.25             1.427856
# 3461  382502.92070         14.48             1.428964
# 3462  396869.88540         13.52             1.263761
# 3463  389222.51350         12.46             1.210876
#
# [3464 rows x 8 columns]

# %%
# merge the sales and customers data for clustering
df_merged = pd.merge(df_sales, df_customers, on='Customer_ID', how='left')
df_merged
# Out:
#      Policy_ID Customer_ID Product_ID Purchase_Date      Premium  \
# 0      P000008     HL00008  POL200008    2022-05-04   861.832800
# 1      P000010     HL00010  POL200016    2022-03-17  1294.144416
# 2      P000015     HL00015  POL200017    2022-05-19  2470.369199
# 3      P000019     HL00019  POL200018    2022-08-03  2032.112144
# 4      P000022     HL00022  POL200015    2023-05-24  1156.180369
# ...        ...         ...        ...           ...          ...
# 3459   P003458     HL03367  POL200009    2022-01-22  5375.637343
# 3460   P003459     HL03367  POL200001    2021-09-16  4798.328801
# 3461   P003462     HL00347  POL200001    2011-06-26  5465.828597
# 3462   P003463     HL00347  POL200016    2012-06-11  5015.488343
# 3463   P003464     HL00347  POL200015    2013-07-02  4713.002623
#
#           Coverage  Tenure_Years  Premium_to_Coverage  Age  Gender  \
# 0      97928.79508          3.62             0.880061   31  Female
# 1     100724.49880          3.75             1.284836   49    Male
# 2     102937.51920          3.58             2.399872   42  Female
# 3      98439.34626          3.37             2.064329   41  Female
# 4     101259.37510          2.56             1.141801   20  Female
# ...            ...           ...                  ...  ...     ...
# 3459  519777.85190          3.90             1.034218   56  Female
# 3460  336051.20600          4.25             1.427856   56  Female
# 3461  382502.92070         14.48             1.428964   50  Female
# 3462  396869.88540         13.52             1.263761   50  Female
# 3463  389222.51350         12.46             1.210876   50  Female
#
#                 City Marital_Status          Education    Occupation  \
# 0            Cardiff         Single   Associate Degree         Nurse
# 1     Stoke-on-Trent        Married          Doctorate        Artist
# 2             London        Widowed          Doctorate        Lawyer
# 3         Manchester        Widowed          Doctorate        Lawyer
# 4         Birmingham        Married  Bachelor's Degree  Entrepreneur
# ...              ...            ...                ...           ...
# 3459          London        Married  Bachelor's Degree       Manager
# 3460          London        Married  Bachelor's Degree       Manager
# 3461      Manchester        Married  Bachelor's Degree       Manager
# 3462      Manchester        Married  Bachelor's Degree       Manager
# 3463      Manchester        Married  Bachelor's Degree       Manager
#
#           Income Preferred_Language Preferred_Channel Preferred_Time
# 0     12648.5040         Portuguese              Text        Anytime
# 1     54920.5920            English              Mail        Morning
# 2     43274.9280            English              Text        Evening
# 3     47331.2040            English              Text        Evening
# 4      7628.8212            English              Text        Evening
# ...          ...                ...               ...            ...
# 3459  64186.7640            English             Phone       Weekends
# 3460  64186.7640            English             Phone       Weekends
# 3461  87828.2280            English              Text        Anytime
# 3462  87828.2280            English              Text        Anytime
# 3463  87828.2280            English              Text        Anytime
#
# [3464 rows x 18 columns]

# %%
# group the data by customer and average the metrics for each customer
df_grouped_customer = df_merged.groupby(['Customer_ID', 'Marital_Status']).agg(
                      Age = ('Age', 'mean'),
                      Income = ('Income', 'mean'),
                      Tenure_Years = ('Tenure_Years', 'mean'),
                      Premium_to_Coverage = ('Premium_to_Coverage',  'mean')
)

# %%
df_grouped_customer = df_grouped_customer.reset_index() # reset the index to free the columns
df_grouped_customer
# Out:
#      Customer_ID Marital_Status   Age      Income  Tenure_Years  \
# 0        HL00001         Single  41.0   18719.316         11.21
# 1        HL00002        Married  50.0   59456.052          1.82
# 2        HL00003       Divorced  33.0   61078.656          3.65
# 3        HL00004        Married  43.0   39333.528          3.02
# 4        HL00005      Separated  36.0   25995.516         10.96
# ...          ...            ...   ...         ...           ...
# 3441     HL03442         Single  42.0   48832.356          4.74
# 3442     HL03443       Divorced  18.0  127478.040          4.61
# 3443     HL03444       Divorced  34.0   97274.124          4.85
# 3444     HL03445        Married  54.0   66348.840         14.24
# 3445     HL03446        Widowed  25.0   60926.220          6.83
#
#       Premium_to_Coverage
# 0                1.236672
# 1                0.794987
# 2                0.902040
# 3                0.719727
# 4                0.954749
# ...                   ...
# 3441             0.774854
# 3442             0.864231
# 3443             0.811720
# 3444             0.852235
# 3445             0.766225
#
# [3446 rows x 6 columns]

# %%
# Extract the columns that are useful for the analysis
df = df_grouped_customer[['Age', 'Marital_Status','Income','Tenure_Years', 'Premium_to_Coverage']].copy()

# %%
df
# Out:
#        Age Marital_Status      Income  Tenure_Years  Premium_to_Coverage
# 0     41.0         Single   18719.316         11.21             1.236672
# 1     50.0        Married   59456.052          1.82             0.794987
# 2     33.0       Divorced   61078.656          3.65             0.902040
# 3     43.0        Married   39333.528          3.02             0.719727
# 4     36.0      Separated   25995.516         10.96             0.954749
# ...    ...            ...         ...           ...                  ...
# 3441  42.0         Single   48832.356          4.74             0.774854
# 3442  18.0       Divorced  127478.040          4.61             0.864231
# 3443  34.0       Divorced   97274.124          4.85             0.811720
# 3444  54.0        Married   66348.840         14.24             0.852235
# 3445  25.0        Widowed   60926.220          6.83             0.766225
#
# [3446 rows x 5 columns]

# %%
# Identify the columns with categorical and numeric labels
categorical_cols = ['Marital_Status']
numerical_cols = ['Age', 'Income', 'Tenure_Years', 'Premium_to_Coverage']

# %%
# Define categorical column indices
categorical_indices = [df.columns.get_loc(col) for col in categorical_cols]
categorical_indices
# Out:
# [1]

# %%
# Define categorical column indices
numeric_indices = [df.columns.get_loc(col) for col in numerical_cols]
numeric_indices
# Out:
# [0, 2, 3, 4]

# %%
# Shows the distribution of each feature

plt.figure(figsize=(12, 24))
colours_val = ['c', 'b', 'r', 'm']

length = len(categorical_indices) + len(numerical_cols)

# Pie Charts for Categorical Features
for j, i in enumerate(categorical_indices):
    plt.subplot(length, 2, j + 1)
    value_counts = df.iloc[:, i].value_counts()
    plt.pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%',
            colors=sns.color_palette("pastel"), startangle=140)
    plt.title(df.columns[i])

# Histograms for Numerical Features
for j, i in enumerate(numeric_indices):
    plt.subplot(length, 2, len(categorical_indices) + j + 1)
    sns.histplot(df.iloc[:, i], kde=True, color=colours_val[j])
    plt.title(df.columns[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# # (5) Feature Engineering
#
# Due to a mix of categorical and numeric data, we prefer K-Prototype to K-means for the segmentation, as the latter only works for numerical data. Before data clustering, we may need to transform raw data into features which can be used in the model.
#
# *   *Categorical labels*: These can be used directly in the K-Prototypes algorithm without any conversion, as it is designed to handle categorical features natively through matching dissimilarities.
#
# *   *Numerical labels*: Scale the numerical features to a range of 0 to 1 using **MinMaxScaler**. We prefer MinMaxScaler over StandardScaler because it bounds all values within the same range, ensuring that each numerical feature contributes equally to the overall distance calculation in this distance-based segmentation algorithm.

# %%
df_c = df.copy()

# %%
# ensure all columns with numerical values are in float data type
for col in numerical_cols:
    df_c[col] = df_c[col].astype('float64')

# %%
# Statistics of the dataset
df_c.describe()
# Out:
#                Age         Income  Tenure_Years  Premium_to_Coverage
# count  3446.000000    3446.000000   3446.000000          3446.000000
# mean     38.705165   60842.116697      6.243227             1.251587
# std      12.234530   34680.122498      4.865412             0.565356
# min      18.000000    7343.839200      1.200000             0.233796
# 25%      29.000000   25272.714000      2.650000             0.747882
# 50%      38.000000   59751.606000      3.710000             1.169621
# 75%      47.000000   85128.669000     10.865000             1.699544
# max      83.000000  168937.560000     21.410000             3.498307

# %%
# scale the numerical variables
scaler = MinMaxScaler()
df_c[numerical_cols] = scaler.fit_transform(df_c[numerical_cols])
df_c
# Out:
#            Age Marital_Status    Income  Tenure_Years  Premium_to_Coverage
# 0     0.353846         Single  0.070396      0.495299             0.307206
# 1     0.492308        Married  0.322489      0.030678             0.171907
# 2     0.230769       Divorced  0.332530      0.121227             0.204700
# 3     0.384615        Married  0.197964      0.090054             0.148853
# 4     0.276923      Separated  0.115423      0.482929             0.220846
# ...        ...            ...       ...           ...                  ...
# 3441  0.369231         Single  0.256746      0.175161             0.165740
# 3442  0.000000       Divorced  0.743434      0.168728             0.193118
# 3443  0.246154       Divorced  0.556521      0.180604             0.177033
# 3444  0.553846        Married  0.365144      0.645225             0.189443
# 3445  0.107692        Widowed  0.331587      0.278575             0.163096
#
# [3446 rows x 5 columns]

# %%
# convert the data to array for clustering in the next step
c_array = df_c.to_numpy()
c_array
# Out:
# array([[0.3538461538461538, 'Single', 0.0703955372998627,
#         0.4952993567540822, 0.30720573831094333],
#        [0.49230769230769234, 'Married', 0.3224890951332064,
#         0.030677882236516588, 0.1719066997474958],
#        [0.23076923076923073, 'Divorced', 0.3325303516372772,
#         0.12122711528946066, 0.2046997214143574],
#        ...,
#        [0.24615384615384617, 'Divorced', 0.5565209115476967,
#         0.1806036615536863, 0.17703255267571788],
#        [0.5538461538461539, 'Married', 0.36514414364546266,
#         0.6452251360712519, 0.1894432559380351],
#        [0.1076923076923077, 'Widowed', 0.33158702290367703,
#         0.2785749628896586, 0.16309617758305803]], dtype=object)

# %% [markdown]
# # (6) Clustering using K-Prototypes
#
# K-prototypes combines the use of minimizing Euclidean distance for numerical labels and comparing matching dissimilarity for categorical labels, to determine the cluster centroids. We locate the optimal k (the no. of clusters) using Elbow Method, where the optimal k is the point that the rate of decrease in **WCSS (Within-Cluster Sum of Squares)** slows down or flattens. WCSS measures the total variance within each cluster.

# %%
# we set k as the number of clusters

costs = {} # a dictionary to store the WCSS (Within-Cluster Sum of Square) for each k
labels = {} # a dictionary to store the predicted cluster labels for each k

range_of_k = range(2,10) # we set k from 2 to 9
for k in range_of_k :
    print("Checking k =", k)
    untrained_model = KPrototypes(n_clusters=k, init='Cao', max_iter=20, random_state=42, verbose=1) # fixed random seed
    trained_model = untrained_model.fit(c_array, categorical=categorical_indices)

    labels[k] = trained_model.labels_ # predicted labels
    costs[k]=trained_model.cost_ # WCSS
# Out:
# Checking k = 2
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 544, ncost: 550.6781230576776
# Run: 1, iteration: 2/20, moves: 68, ncost: 550.2686812128335
# Run: 1, iteration: 3/20, moves: 18, ncost: 550.2056189664319
# Run: 1, iteration: 4/20, moves: 3, ncost: 550.2040341824518
# Run: 1, iteration: 5/20, moves: 1, ncost: 550.2038108101211
# Run: 1, iteration: 6/20, moves: 0, ncost: 550.2038108101211
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1092, ncost: 556.4568208915592
# Run: 2, iteration: 2/20, moves: 232, ncost: 550.7413395264357
# Run: 2, iteration: 3/20, moves: 53, ncost: 550.2584739468634
# Run: 2, iteration: 4/20, moves: 16, ncost: 550.206337023497
# Run: 2, iteration: 5/20, moves: 2, ncost: 550.2051528988368
# Run: 2, iteration: 6/20, moves: 1, ncost: 550.2049299451696
# Run: 2, iteration: 7/20, moves: 0, ncost: 550.2049299451696
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 645, ncost: 597.5033051649691
# Run: 3, iteration: 2/20, moves: 307, ncost: 574.8532350384066
# Run: 3, iteration: 3/20, moves: 394, ncost: 532.0063836984882
# Run: 3, iteration: 4/20, moves: 150, ncost: 525.0197294812659
# Run: 3, iteration: 5/20, moves: 12, ncost: 524.9999929518184
# Run: 3, iteration: 6/20, moves: 0, ncost: 524.9999929518184
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 540, ncost: 593.305548453892
# Run: 4, iteration: 2/20, moves: 81, ncost: 592.4243726336281
# Run: 4, iteration: 3/20, moves: 8, ncost: 592.4156288356767
# Run: 4, iteration: 4/20, moves: 0, ncost: 592.4156288356767
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 847, ncost: 533.0040091935359
# Run: 5, iteration: 2/20, moves: 184, ncost: 525.0205346380438
# Run: 5, iteration: 3/20, moves: 12, ncost: 524.9999929518182
# Run: 5, iteration: 4/20, moves: 0, ncost: 524.9999929518182
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 974, ncost: 527.2151215121775
# Run: 6, iteration: 2/20, moves: 121, ncost: 525.0113339129724
# Run: 6, iteration: 3/20, moves: 9, ncost: 524.9999929518182
# Run: 6, iteration: 4/20, moves: 0, ncost: 524.9999929518182
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 581, ncost: 525.4364627284466
# Run: 7, iteration: 2/20, moves: 60, ncost: 525.0036740187057
# Run: 7, iteration: 3/20, moves: 5, ncost: 524.9999929518182
# Run: 7, iteration: 4/20, moves: 0, ncost: 524.9999929518182
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 945, ncost: 550.7425437937533
# Run: 8, iteration: 2/20, moves: 100, ncost: 550.2407329515023
# Run: 8, iteration: 3/20, moves: 15, ncost: 550.2049299451706
# Run: 8, iteration: 4/20, moves: 0, ncost: 550.2049299451706
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 218, ncost: 525.0040791309323
# Run: 9, iteration: 2/20, moves: 7, ncost: 524.9999929518182
# Run: 9, iteration: 3/20, moves: 0, ncost: 524.9999929518182
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 556, ncost: 550.254703702908
# Run: 10, iteration: 2/20, moves: 50, ncost: 550.2047444189697
# Run: 10, iteration: 3/20, moves: 2, ncost: 550.2038108101215
# Run: 10, iteration: 4/20, moves: 0, ncost: 550.2038108101215
# Best run was number 5
# Checking k = 3
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 881, ncost: 373.8582185807469
# Run: 1, iteration: 2/20, moves: 728, ncost: 308.21354775460003
# Run: 1, iteration: 3/20, moves: 16, ncost: 308.1935000909631
# Run: 1, iteration: 4/20, moves: 0, ncost: 308.1935000909631
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1329, ncost: 310.74528133859764
# Run: 2, iteration: 2/20, moves: 219, ncost: 308.19684189613855
# Run: 2, iteration: 3/20, moves: 6, ncost: 308.19350009096274
# Run: 2, iteration: 4/20, moves: 0, ncost: 308.19350009096274
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1234, ncost: 380.713533661987
# Run: 3, iteration: 2/20, moves: 776, ncost: 308.5688500315642
# Run: 3, iteration: 3/20, moves: 51, ncost: 308.1948818197427
# Run: 3, iteration: 4/20, moves: 3, ncost: 308.1935000909631
# Run: 3, iteration: 5/20, moves: 0, ncost: 308.1935000909631
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 932, ncost: 308.3460431708727
# Run: 4, iteration: 2/20, moves: 43, ncost: 308.1947765305303
# Run: 4, iteration: 3/20, moves: 2, ncost: 308.19350009096297
# Run: 4, iteration: 4/20, moves: 0, ncost: 308.19350009096297
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 815, ncost: 308.8077312493226
# Run: 5, iteration: 2/20, moves: 80, ncost: 308.19718738140386
# Run: 5, iteration: 3/20, moves: 6, ncost: 308.19350009096274
# Run: 5, iteration: 4/20, moves: 0, ncost: 308.19350009096274
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 860, ncost: 308.45667929740546
# Run: 6, iteration: 2/20, moves: 66, ncost: 308.1960561865339
# Run: 6, iteration: 3/20, moves: 4, ncost: 308.19350009096274
# Run: 6, iteration: 4/20, moves: 0, ncost: 308.19350009096274
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 418, ncost: 513.2441072527099
# Run: 7, iteration: 2/20, moves: 259, ncost: 503.4248546516444
# Run: 7, iteration: 3/20, moves: 185, ncost: 500.14185415504784
# Run: 7, iteration: 4/20, moves: 45, ncost: 500.0073104064781
# Run: 7, iteration: 5/20, moves: 5, ncost: 500.00520419306355
# Run: 7, iteration: 6/20, moves: 0, ncost: 500.00520419306355
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1468, ncost: 310.2505447662882
# Run: 8, iteration: 2/20, moves: 121, ncost: 308.1946189961889
# Run: 8, iteration: 3/20, moves: 3, ncost: 308.1935000909628
# Run: 8, iteration: 4/20, moves: 0, ncost: 308.1935000909628
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1124, ncost: 316.12211017615186
# Run: 9, iteration: 2/20, moves: 239, ncost: 308.23980338785015
# Run: 9, iteration: 3/20, moves: 19, ncost: 308.1935000909627
# Run: 9, iteration: 4/20, moves: 0, ncost: 308.1935000909627
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 746, ncost: 308.2679512140813
# Run: 10, iteration: 2/20, moves: 27, ncost: 308.19477653053036
# Run: 10, iteration: 3/20, moves: 2, ncost: 308.1935000909627
# Run: 10, iteration: 4/20, moves: 0, ncost: 308.1935000909627
# Best run was number 9
# Checking k = 4
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 1212, ncost: 328.1910453147951
# Run: 1, iteration: 2/20, moves: 619, ncost: 276.5775294533675
# Run: 1, iteration: 3/20, moves: 153, ncost: 272.1810650482727
# Run: 1, iteration: 4/20, moves: 63, ncost: 271.9278263263994
# Run: 1, iteration: 5/20, moves: 35, ncost: 271.86372754218354
# Run: 1, iteration: 6/20, moves: 23, ncost: 271.83331858139303
# Run: 1, iteration: 7/20, moves: 1, ncost: 271.83324988141726
# Run: 1, iteration: 8/20, moves: 0, ncost: 271.83324988141726
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1492, ncost: 261.16767768076346
# Run: 2, iteration: 2/20, moves: 284, ncost: 255.4033353606683
# Run: 2, iteration: 3/20, moves: 5, ncost: 255.40030800855513
# Run: 2, iteration: 4/20, moves: 1, ncost: 255.40029399126772
# Run: 2, iteration: 5/20, moves: 0, ncost: 255.40029399126772
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1096, ncost: 301.93720058396565
# Run: 3, iteration: 2/20, moves: 541, ncost: 275.75127378916926
# Run: 3, iteration: 3/20, moves: 183, ncost: 271.90020938643204
# Run: 3, iteration: 4/20, moves: 34, ncost: 271.8333062215266
# Run: 3, iteration: 5/20, moves: 1, ncost: 271.8332944062218
# Run: 3, iteration: 6/20, moves: 0, ncost: 271.8332944062218
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1013, ncost: 297.14498275466474
# Run: 4, iteration: 2/20, moves: 141, ncost: 296.06544080589055
# Run: 4, iteration: 3/20, moves: 105, ncost: 295.06777971688695
# Run: 4, iteration: 4/20, moves: 163, ncost: 291.81973769910974
# Run: 4, iteration: 5/20, moves: 340, ncost: 271.90590875200627
# Run: 4, iteration: 6/20, moves: 407, ncost: 255.54448438666023
# Run: 4, iteration: 7/20, moves: 39, ncost: 255.40120803584244
# Run: 4, iteration: 8/20, moves: 3, ncost: 255.40029399126783
# Run: 4, iteration: 9/20, moves: 0, ncost: 255.40029399126783
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 1061, ncost: 280.2985147433851
# Run: 5, iteration: 2/20, moves: 263, ncost: 272.36112459092317
# Run: 5, iteration: 3/20, moves: 70, ncost: 271.91480067338676
# Run: 5, iteration: 4/20, moves: 24, ncost: 271.87072644097657
# Run: 5, iteration: 5/20, moves: 19, ncost: 271.83945960864514
# Run: 5, iteration: 6/20, moves: 9, ncost: 271.83331858139303
# Run: 5, iteration: 7/20, moves: 1, ncost: 271.8332498814172
# Run: 5, iteration: 8/20, moves: 0, ncost: 271.8332498814172
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 1232, ncost: 274.574862197066
# Run: 6, iteration: 2/20, moves: 140, ncost: 272.6504422531159
# Run: 6, iteration: 3/20, moves: 15, ncost: 272.633162214753
# Run: 6, iteration: 4/20, moves: 1, ncost: 272.63273960575344
# Run: 6, iteration: 5/20, moves: 0, ncost: 272.63273960575344
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 753, ncost: 431.1329552754546
# Run: 7, iteration: 2/20, moves: 999, ncost: 295.6016412293285
# Run: 7, iteration: 3/20, moves: 361, ncost: 284.1724742308675
# Run: 7, iteration: 4/20, moves: 132, ncost: 282.65903617265843
# Run: 7, iteration: 5/20, moves: 30, ncost: 282.5757231844697
# Run: 7, iteration: 6/20, moves: 2, ncost: 282.5752162114975
# Run: 7, iteration: 7/20, moves: 1, ncost: 282.5750958790694
# Run: 7, iteration: 8/20, moves: 0, ncost: 282.5750958790694
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1560, ncost: 278.70084929133276
# Run: 8, iteration: 2/20, moves: 328, ncost: 272.117952300544
# Run: 8, iteration: 3/20, moves: 46, ncost: 271.9001449585637
# Run: 8, iteration: 4/20, moves: 25, ncost: 271.85618776161044
# Run: 8, iteration: 5/20, moves: 19, ncost: 271.833318581393
# Run: 8, iteration: 6/20, moves: 1, ncost: 271.83324988141726
# Run: 8, iteration: 7/20, moves: 0, ncost: 271.83324988141726
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1157, ncost: 255.90717559710615
# Run: 9, iteration: 2/20, moves: 150, ncost: 255.12676908704745
# Run: 9, iteration: 3/20, moves: 5, ncost: 255.12544027058956
# Run: 9, iteration: 4/20, moves: 3, ncost: 255.1253545445773
# Run: 9, iteration: 5/20, moves: 0, ncost: 255.1253545445773
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 1083, ncost: 255.52204259617548
# Run: 10, iteration: 2/20, moves: 106, ncost: 255.40211212541968
# Run: 10, iteration: 3/20, moves: 8, ncost: 255.39993205705943
# Run: 10, iteration: 4/20, moves: 1, ncost: 255.39991815132083
# Run: 10, iteration: 5/20, moves: 0, ncost: 255.39991815132083
# Best run was number 9
# Checking k = 5
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 892, ncost: 238.8126582883285
# Run: 1, iteration: 2/20, moves: 118, ncost: 236.3466746248277
# Run: 1, iteration: 3/20, moves: 47, ncost: 236.24019090634903
# Run: 1, iteration: 4/20, moves: 20, ncost: 236.2056011528966
# Run: 1, iteration: 5/20, moves: 21, ncost: 236.1737113408255
# Run: 1, iteration: 6/20, moves: 8, ncost: 236.16830045927918
# Run: 1, iteration: 7/20, moves: 1, ncost: 236.1681691337744
# Run: 1, iteration: 8/20, moves: 1, ncost: 236.16812653487744
# Run: 1, iteration: 9/20, moves: 0, ncost: 236.16812653487744
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1206, ncost: 251.17855484572064
# Run: 2, iteration: 2/20, moves: 297, ncost: 247.66188051062187
# Run: 2, iteration: 3/20, moves: 49, ncost: 247.49560314158947
# Run: 2, iteration: 4/20, moves: 14, ncost: 247.47518006854887
# Run: 2, iteration: 5/20, moves: 8, ncost: 247.459970412389
# Run: 2, iteration: 6/20, moves: 14, ncost: 247.44303382601905
# Run: 2, iteration: 7/20, moves: 2, ncost: 247.4423849803144
# Run: 2, iteration: 8/20, moves: 1, ncost: 247.4422774444553
# Run: 2, iteration: 9/20, moves: 0, ncost: 247.4422774444553
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1572, ncost: 232.23258556075925
# Run: 3, iteration: 2/20, moves: 347, ncost: 221.28386902993645
# Run: 3, iteration: 3/20, moves: 90, ncost: 219.4336552800481
# Run: 3, iteration: 4/20, moves: 41, ncost: 219.28081305683492
# Run: 3, iteration: 5/20, moves: 17, ncost: 219.26458648137177
# Run: 3, iteration: 6/20, moves: 2, ncost: 219.26455508700295
# Run: 3, iteration: 7/20, moves: 0, ncost: 219.26455508700295
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1140, ncost: 246.06259210137807
# Run: 4, iteration: 2/20, moves: 75, ncost: 246.00625910068987
# Run: 4, iteration: 3/20, moves: 1, ncost: 246.00584709610558
# Run: 4, iteration: 4/20, moves: 1, ncost: 246.00576870829923
# Run: 4, iteration: 5/20, moves: 0, ncost: 246.00576870829923
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 1103, ncost: 231.08303449905748
# Run: 5, iteration: 2/20, moves: 117, ncost: 230.09263794869452
# Run: 5, iteration: 3/20, moves: 57, ncost: 229.92283585411747
# Run: 5, iteration: 4/20, moves: 21, ncost: 229.89886360547038
# Run: 5, iteration: 5/20, moves: 8, ncost: 229.885304513212
# Run: 5, iteration: 6/20, moves: 4, ncost: 229.88251545195297
# Run: 5, iteration: 7/20, moves: 0, ncost: 229.88251545195297
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 454, ncost: 263.3961798580319
# Run: 6, iteration: 2/20, moves: 114, ncost: 262.1983154495762
# Run: 6, iteration: 3/20, moves: 31, ncost: 262.04095241591585
# Run: 6, iteration: 4/20, moves: 21, ncost: 261.9606219813102
# Run: 6, iteration: 5/20, moves: 21, ncost: 261.86758782693653
# Run: 6, iteration: 6/20, moves: 32, ncost: 261.6404161512183
# Run: 6, iteration: 7/20, moves: 24, ncost: 261.52362662813744
# Run: 6, iteration: 8/20, moves: 7, ncost: 261.51162776451156
# Run: 6, iteration: 9/20, moves: 4, ncost: 261.5067498109949
# Run: 6, iteration: 10/20, moves: 0, ncost: 261.5067498109949
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 1568, ncost: 298.9089198156927
# Run: 7, iteration: 2/20, moves: 540, ncost: 277.8547479044736
# Run: 7, iteration: 3/20, moves: 139, ncost: 276.14253725296425
# Run: 7, iteration: 4/20, moves: 58, ncost: 275.7336346291585
# Run: 7, iteration: 5/20, moves: 55, ncost: 275.1971905993737
# Run: 7, iteration: 6/20, moves: 61, ncost: 274.7531042531797
# Run: 7, iteration: 7/20, moves: 41, ncost: 274.5179964019644
# Run: 7, iteration: 8/20, moves: 24, ncost: 274.44790506500675
# Run: 7, iteration: 9/20, moves: 15, ncost: 274.423825462013
# Run: 7, iteration: 10/20, moves: 4, ncost: 274.4195137112681
# Run: 7, iteration: 11/20, moves: 5, ncost: 274.41643100853946
# Run: 7, iteration: 12/20, moves: 0, ncost: 274.41643100853946
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1120, ncost: 239.8314041562568
# Run: 8, iteration: 2/20, moves: 203, ncost: 236.25162620318787
# Run: 8, iteration: 3/20, moves: 31, ncost: 236.17051479614662
# Run: 8, iteration: 4/20, moves: 4, ncost: 236.16830045927904
# Run: 8, iteration: 5/20, moves: 1, ncost: 236.16816913377426
# Run: 8, iteration: 6/20, moves: 1, ncost: 236.1681265348774
# Run: 8, iteration: 7/20, moves: 0, ncost: 236.1681265348774
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1170, ncost: 239.92751018280254
# Run: 9, iteration: 2/20, moves: 168, ncost: 238.32976395930362
# Run: 9, iteration: 3/20, moves: 8, ncost: 238.31694258864903
# Run: 9, iteration: 4/20, moves: 18, ncost: 238.1695716504618
# Run: 9, iteration: 5/20, moves: 7, ncost: 238.16118173197512
# Run: 9, iteration: 6/20, moves: 0, ncost: 238.16118173197512
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 1349, ncost: 219.64661766214675
# Run: 10, iteration: 2/20, moves: 156, ncost: 219.36627562320552
# Run: 10, iteration: 3/20, moves: 40, ncost: 219.3010758049385
# Run: 10, iteration: 4/20, moves: 22, ncost: 219.27191920817043
# Run: 10, iteration: 5/20, moves: 10, ncost: 219.26473494010617
# Run: 10, iteration: 6/20, moves: 2, ncost: 219.26450536513187
# Run: 10, iteration: 7/20, moves: 0, ncost: 219.26450536513187
# Best run was number 10
# Checking k = 6
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 843, ncost: 194.09003904002807
# Run: 1, iteration: 2/20, moves: 540, ncost: 183.838851343055
# Run: 1, iteration: 3/20, moves: 65, ncost: 183.64082748008366
# Run: 1, iteration: 4/20, moves: 6, ncost: 183.63802069114388
# Run: 1, iteration: 5/20, moves: 9, ncost: 183.63256952556037
# Run: 1, iteration: 6/20, moves: 1, ncost: 183.63242580882093
# Run: 1, iteration: 7/20, moves: 0, ncost: 183.63242580882093
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1401, ncost: 226.4165094418564
# Run: 2, iteration: 2/20, moves: 673, ncost: 183.7557130660441
# Run: 2, iteration: 3/20, moves: 78, ncost: 183.64970102311858
# Run: 2, iteration: 4/20, moves: 14, ncost: 183.6427562932015
# Run: 2, iteration: 5/20, moves: 11, ncost: 183.63552098925334
# Run: 2, iteration: 6/20, moves: 8, ncost: 183.63276677149108
# Run: 2, iteration: 7/20, moves: 5, ncost: 183.63248865643155
# Run: 2, iteration: 8/20, moves: 1, ncost: 183.63247459487843
# Run: 2, iteration: 9/20, moves: 0, ncost: 183.63247459487843
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1820, ncost: 222.8126262269968
# Run: 3, iteration: 2/20, moves: 404, ncost: 210.59163038709113
# Run: 3, iteration: 3/20, moves: 135, ncost: 208.54819245207008
# Run: 3, iteration: 4/20, moves: 62, ncost: 208.41966111975196
# Run: 3, iteration: 5/20, moves: 20, ncost: 208.4050348681706
# Run: 3, iteration: 6/20, moves: 9, ncost: 208.4029150779539
# Run: 3, iteration: 7/20, moves: 0, ncost: 208.4029150779539
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1452, ncost: 236.10494079895034
# Run: 4, iteration: 2/20, moves: 164, ncost: 235.37734194181974
# Run: 4, iteration: 3/20, moves: 56, ncost: 235.2904441247116
# Run: 4, iteration: 4/20, moves: 21, ncost: 235.2762482156577
# Run: 4, iteration: 5/20, moves: 12, ncost: 235.27092170882543
# Run: 4, iteration: 6/20, moves: 10, ncost: 235.2682690771336
# Run: 4, iteration: 7/20, moves: 5, ncost: 235.2678052279343
# Run: 4, iteration: 8/20, moves: 0, ncost: 235.2678052279343
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 968, ncost: 204.95752777591875
# Run: 5, iteration: 2/20, moves: 253, ncost: 201.92046967511075
# Run: 5, iteration: 3/20, moves: 99, ncost: 201.3985451312763
# Run: 5, iteration: 4/20, moves: 32, ncost: 201.3143730601374
# Run: 5, iteration: 5/20, moves: 18, ncost: 201.28277689936792
# Run: 5, iteration: 6/20, moves: 8, ncost: 201.27348436088786
# Run: 5, iteration: 7/20, moves: 1, ncost: 201.2728804704877
# Run: 5, iteration: 8/20, moves: 0, ncost: 201.2728804704877
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 742, ncost: 252.83237113131943
# Run: 6, iteration: 2/20, moves: 246, ncost: 250.72746863912147
# Run: 6, iteration: 3/20, moves: 154, ncost: 249.71328670617154
# Run: 6, iteration: 4/20, moves: 146, ncost: 248.23150157080607
# Run: 6, iteration: 5/20, moves: 238, ncost: 241.60208182158456
# Run: 6, iteration: 6/20, moves: 457, ncost: 212.3831010983692
# Run: 6, iteration: 7/20, moves: 223, ncost: 208.77781450520834
# Run: 6, iteration: 8/20, moves: 9, ncost: 208.7688174979046
# Run: 6, iteration: 9/20, moves: 1, ncost: 208.7687442783411
# Run: 6, iteration: 10/20, moves: 0, ncost: 208.7687442783411
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 949, ncost: 223.09683260093237
# Run: 7, iteration: 2/20, moves: 163, ncost: 222.03884859868487
# Run: 7, iteration: 3/20, moves: 44, ncost: 221.84718685658115
# Run: 7, iteration: 4/20, moves: 24, ncost: 221.78167024935334
# Run: 7, iteration: 5/20, moves: 11, ncost: 221.76486590790776
# Run: 7, iteration: 6/20, moves: 8, ncost: 221.75608726415786
# Run: 7, iteration: 7/20, moves: 2, ncost: 221.7544430546753
# Run: 7, iteration: 8/20, moves: 0, ncost: 221.7544430546753
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1247, ncost: 234.4250829249049
# Run: 8, iteration: 2/20, moves: 496, ncost: 220.3130871180901
# Run: 8, iteration: 3/20, moves: 126, ncost: 219.0917408596278
# Run: 8, iteration: 4/20, moves: 41, ncost: 218.9177996102964
# Run: 8, iteration: 5/20, moves: 22, ncost: 218.85053368290818
# Run: 8, iteration: 6/20, moves: 7, ncost: 218.84355183570995
# Run: 8, iteration: 7/20, moves: 4, ncost: 218.83628129122135
# Run: 8, iteration: 8/20, moves: 2, ncost: 218.8347168831837
# Run: 8, iteration: 9/20, moves: 0, ncost: 218.8347168831837
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1988, ncost: 240.50568487768967
# Run: 9, iteration: 2/20, moves: 712, ncost: 203.92853715660112
# Run: 9, iteration: 3/20, moves: 112, ncost: 202.86289324046547
# Run: 9, iteration: 4/20, moves: 13, ncost: 202.8101638167727
# Run: 9, iteration: 5/20, moves: 20, ncost: 202.71679965286745
# Run: 9, iteration: 6/20, moves: 4, ncost: 202.7137870190149
# Run: 9, iteration: 7/20, moves: 1, ncost: 202.71373457327016
# Run: 9, iteration: 8/20, moves: 0, ncost: 202.71373457327016
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 1012, ncost: 216.75071183239808
# Run: 10, iteration: 2/20, moves: 301, ncost: 206.58495823085786
# Run: 10, iteration: 3/20, moves: 160, ncost: 202.4117757622759
# Run: 10, iteration: 4/20, moves: 45, ncost: 202.14822141584736
# Run: 10, iteration: 5/20, moves: 5, ncost: 202.14684706478016
# Run: 10, iteration: 6/20, moves: 0, ncost: 202.14684706478016
# Best run was number 1
# Checking k = 7
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 848, ncost: 190.78987911780015
# Run: 1, iteration: 2/20, moves: 596, ncost: 177.99812237817153
# Run: 1, iteration: 3/20, moves: 144, ncost: 175.34012772356135
# Run: 1, iteration: 4/20, moves: 118, ncost: 173.7585342773861
# Run: 1, iteration: 5/20, moves: 105, ncost: 171.36700507302425
# Run: 1, iteration: 6/20, moves: 134, ncost: 168.42167542889746
# Run: 1, iteration: 7/20, moves: 106, ncost: 166.96220567800071
# Run: 1, iteration: 8/20, moves: 61, ncost: 166.5498176608081
# Run: 1, iteration: 9/20, moves: 36, ncost: 166.38770611441328
# Run: 1, iteration: 10/20, moves: 23, ncost: 166.32772000342047
# Run: 1, iteration: 11/20, moves: 8, ncost: 166.31433493346944
# Run: 1, iteration: 12/20, moves: 1, ncost: 166.3137895924757
# Run: 1, iteration: 13/20, moves: 0, ncost: 166.3137895924757
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1534, ncost: 172.43750584595404
# Run: 2, iteration: 2/20, moves: 463, ncost: 166.8947306856983
# Run: 2, iteration: 3/20, moves: 106, ncost: 166.39573862522766
# Run: 2, iteration: 4/20, moves: 26, ncost: 166.33023035674023
# Run: 2, iteration: 5/20, moves: 11, ncost: 166.31438757392297
# Run: 2, iteration: 6/20, moves: 1, ncost: 166.3138422329293
# Run: 2, iteration: 7/20, moves: 0, ncost: 166.3138422329293
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1419, ncost: 185.974793097489
# Run: 3, iteration: 2/20, moves: 391, ncost: 176.39167876652058
# Run: 3, iteration: 3/20, moves: 132, ncost: 173.33377452264895
# Run: 3, iteration: 4/20, moves: 29, ncost: 173.29041190136897
# Run: 3, iteration: 5/20, moves: 49, ncost: 173.00431383177954
# Run: 3, iteration: 6/20, moves: 21, ncost: 172.95610595471538
# Run: 3, iteration: 7/20, moves: 0, ncost: 172.95610595471538
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1513, ncost: 212.91652069137945
# Run: 4, iteration: 2/20, moves: 241, ncost: 210.9070409625955
# Run: 4, iteration: 3/20, moves: 90, ncost: 210.6196715439256
# Run: 4, iteration: 4/20, moves: 32, ncost: 210.5535816466154
# Run: 4, iteration: 5/20, moves: 13, ncost: 210.54352595243748
# Run: 4, iteration: 6/20, moves: 5, ncost: 210.54290826708723
# Run: 4, iteration: 7/20, moves: 4, ncost: 210.54190277741202
# Run: 4, iteration: 8/20, moves: 3, ncost: 210.54134810912132
# Run: 4, iteration: 9/20, moves: 2, ncost: 210.54108958407843
# Run: 4, iteration: 10/20, moves: 1, ncost: 210.54103270877218
# Run: 4, iteration: 11/20, moves: 0, ncost: 210.54103270877218
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 960, ncost: 196.20749745666083
# Run: 5, iteration: 2/20, moves: 164, ncost: 194.35916907282797
# Run: 5, iteration: 3/20, moves: 70, ncost: 193.91999923184352
# Run: 5, iteration: 4/20, moves: 41, ncost: 193.7593185925367
# Run: 5, iteration: 5/20, moves: 9, ncost: 193.7417525247339
# Run: 5, iteration: 6/20, moves: 3, ncost: 193.73914458680892
# Run: 5, iteration: 7/20, moves: 7, ncost: 193.73226071697013
# Run: 5, iteration: 8/20, moves: 15, ncost: 193.71078571667942
# Run: 5, iteration: 9/20, moves: 4, ncost: 193.70673613593712
# Run: 5, iteration: 10/20, moves: 1, ncost: 193.7064558626552
# Run: 5, iteration: 11/20, moves: 0, ncost: 193.7064558626552
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 792, ncost: 247.68423182294117
# Run: 6, iteration: 2/20, moves: 213, ncost: 246.20347217248695
# Run: 6, iteration: 3/20, moves: 142, ncost: 245.20524861746955
# Run: 6, iteration: 4/20, moves: 157, ncost: 243.5348591875438
# Run: 6, iteration: 5/20, moves: 235, ncost: 237.03864465033917
# Run: 6, iteration: 6/20, moves: 441, ncost: 207.8273944420539
# Run: 6, iteration: 7/20, moves: 219, ncost: 204.26321622600398
# Run: 6, iteration: 8/20, moves: 11, ncost: 204.2506728606571
# Run: 6, iteration: 9/20, moves: 4, ncost: 204.2494879632968
# Run: 6, iteration: 10/20, moves: 0, ncost: 204.2494879632968
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 1260, ncost: 188.58119908457746
# Run: 7, iteration: 2/20, moves: 252, ncost: 187.1723012345581
# Run: 7, iteration: 3/20, moves: 82, ncost: 186.9087883895701
# Run: 7, iteration: 4/20, moves: 25, ncost: 186.86367150629437
# Run: 7, iteration: 5/20, moves: 10, ncost: 186.84889198838036
# Run: 7, iteration: 6/20, moves: 4, ncost: 186.84631844741597
# Run: 7, iteration: 7/20, moves: 2, ncost: 186.8458802591148
# Run: 7, iteration: 8/20, moves: 0, ncost: 186.8458802591148
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1053, ncost: 172.66489506584668
# Run: 8, iteration: 2/20, moves: 337, ncost: 166.93864853272999
# Run: 8, iteration: 3/20, moves: 89, ncost: 166.3303077825672
# Run: 8, iteration: 4/20, moves: 31, ncost: 166.22575476692836
# Run: 8, iteration: 5/20, moves: 12, ncost: 166.211919067926
# Run: 8, iteration: 6/20, moves: 0, ncost: 166.211919067926
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1623, ncost: 208.87311667265317
# Run: 9, iteration: 2/20, moves: 368, ncost: 196.54030660565363
# Run: 9, iteration: 3/20, moves: 63, ncost: 195.7398522613352
# Run: 9, iteration: 4/20, moves: 58, ncost: 194.75185868053973
# Run: 9, iteration: 5/20, moves: 65, ncost: 193.9196158728162
# Run: 9, iteration: 6/20, moves: 59, ncost: 193.4016489489373
# Run: 9, iteration: 7/20, moves: 50, ncost: 193.04984286247014
# Run: 9, iteration: 8/20, moves: 39, ncost: 192.86790360100443
# Run: 9, iteration: 9/20, moves: 12, ncost: 192.85023868759794
# Run: 9, iteration: 10/20, moves: 6, ncost: 192.84588863399904
# Run: 9, iteration: 11/20, moves: 2, ncost: 192.8444885692803
# Run: 9, iteration: 12/20, moves: 0, ncost: 192.8444885692803
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 896, ncost: 208.25630855800742
# Run: 10, iteration: 2/20, moves: 260, ncost: 198.64297639997605
# Run: 10, iteration: 3/20, moves: 273, ncost: 184.06441025959887
# Run: 10, iteration: 4/20, moves: 241, ncost: 179.01761117297423
# Run: 10, iteration: 5/20, moves: 107, ncost: 178.11865408652884
# Run: 10, iteration: 6/20, moves: 44, ncost: 177.97063567016227
# Run: 10, iteration: 7/20, moves: 20, ncost: 177.93342980694428
# Run: 10, iteration: 8/20, moves: 10, ncost: 177.92534093750973
# Run: 10, iteration: 9/20, moves: 9, ncost: 177.9164281581817
# Run: 10, iteration: 10/20, moves: 7, ncost: 177.9097388977464
# Run: 10, iteration: 11/20, moves: 3, ncost: 177.9090423776592
# Run: 10, iteration: 12/20, moves: 0, ncost: 177.9090423776592
# Best run was number 8
# Checking k = 8
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 1070, ncost: 177.75920940583043
# Run: 1, iteration: 2/20, moves: 564, ncost: 170.2077284824254
# Run: 1, iteration: 3/20, moves: 227, ncost: 167.32614925634326
# Run: 1, iteration: 4/20, moves: 187, ncost: 162.80166638921364
# Run: 1, iteration: 5/20, moves: 199, ncost: 157.99323694812034
# Run: 1, iteration: 6/20, moves: 111, ncost: 156.46454318178223
# Run: 1, iteration: 7/20, moves: 75, ncost: 155.99927264786334
# Run: 1, iteration: 8/20, moves: 25, ncost: 155.8912726770115
# Run: 1, iteration: 9/20, moves: 17, ncost: 155.85685791807626
# Run: 1, iteration: 10/20, moves: 11, ncost: 155.82890451327356
# Run: 1, iteration: 11/20, moves: 6, ncost: 155.82316607930065
# Run: 1, iteration: 12/20, moves: 3, ncost: 155.8210491482887
# Run: 1, iteration: 13/20, moves: 2, ncost: 155.82061098965917
# Run: 1, iteration: 14/20, moves: 0, ncost: 155.82061098965917
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1543, ncost: 161.3989668227737
# Run: 2, iteration: 2/20, moves: 490, ncost: 159.8397745682445
# Run: 2, iteration: 3/20, moves: 64, ncost: 159.6739051273532
# Run: 2, iteration: 4/20, moves: 48, ncost: 159.59354872131732
# Run: 2, iteration: 5/20, moves: 27, ncost: 159.56571935542328
# Run: 2, iteration: 6/20, moves: 18, ncost: 159.54468513476294
# Run: 2, iteration: 7/20, moves: 9, ncost: 159.54256957215728
# Run: 2, iteration: 8/20, moves: 1, ncost: 159.54249407106187
# Run: 2, iteration: 9/20, moves: 0, ncost: 159.54249407106187
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1492, ncost: 182.16263455380357
# Run: 3, iteration: 2/20, moves: 482, ncost: 172.2551640047443
# Run: 3, iteration: 3/20, moves: 134, ncost: 168.7554775456525
# Run: 3, iteration: 4/20, moves: 32, ncost: 168.67556595937617
# Run: 3, iteration: 5/20, moves: 33, ncost: 168.52971743925727
# Run: 3, iteration: 6/20, moves: 40, ncost: 168.34390702460954
# Run: 3, iteration: 7/20, moves: 7, ncost: 168.34154485817442
# Run: 3, iteration: 8/20, moves: 0, ncost: 168.34154485817442
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1354, ncost: 199.60660741444886
# Run: 4, iteration: 2/20, moves: 244, ncost: 174.88600559663078
# Run: 4, iteration: 3/20, moves: 397, ncost: 174.4353428013548
# Run: 4, iteration: 4/20, moves: 45, ncost: 174.34697951441765
# Run: 4, iteration: 5/20, moves: 37, ncost: 174.263136418334
# Run: 4, iteration: 6/20, moves: 19, ncost: 174.2461339019704
# Run: 4, iteration: 7/20, moves: 15, ncost: 174.21658001314896
# Run: 4, iteration: 8/20, moves: 14, ncost: 174.19796941425224
# Run: 4, iteration: 9/20, moves: 14, ncost: 174.18323703958256
# Run: 4, iteration: 10/20, moves: 18, ncost: 174.17202614237593
# Run: 4, iteration: 11/20, moves: 14, ncost: 174.15956085040733
# Run: 4, iteration: 12/20, moves: 10, ncost: 174.15185169743603
# Run: 4, iteration: 13/20, moves: 7, ncost: 174.14693858327723
# Run: 4, iteration: 14/20, moves: 18, ncost: 174.12307111209384
# Run: 4, iteration: 15/20, moves: 21, ncost: 174.10142882894155
# Run: 4, iteration: 16/20, moves: 10, ncost: 174.09749849693017
# Run: 4, iteration: 17/20, moves: 2, ncost: 174.0965738019805
# Run: 4, iteration: 18/20, moves: 5, ncost: 174.0950471336093
# Run: 4, iteration: 19/20, moves: 1, ncost: 174.09495679230608
# Run: 4, iteration: 20/20, moves: 0, ncost: 174.09495679230608
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 975, ncost: 185.8440301521789
# Run: 5, iteration: 2/20, moves: 174, ncost: 184.03786385465787
# Run: 5, iteration: 3/20, moves: 87, ncost: 183.41627553232996
# Run: 5, iteration: 4/20, moves: 56, ncost: 183.19591788779564
# Run: 5, iteration: 5/20, moves: 21, ncost: 183.1506611997359
# Run: 5, iteration: 6/20, moves: 6, ncost: 183.14522250115624
# Run: 5, iteration: 7/20, moves: 2, ncost: 183.14466000967505
# Run: 5, iteration: 8/20, moves: 0, ncost: 183.14466000967505
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 814, ncost: 241.47241678682397
# Run: 6, iteration: 2/20, moves: 299, ncost: 236.84372455159945
# Run: 6, iteration: 3/20, moves: 296, ncost: 232.20892082879482
# Run: 6, iteration: 4/20, moves: 181, ncost: 230.65529367063925
# Run: 6, iteration: 5/20, moves: 239, ncost: 225.12686224808806
# Run: 6, iteration: 6/20, moves: 426, ncost: 196.21755634764688
# Run: 6, iteration: 7/20, moves: 264, ncost: 190.73228473195184
# Run: 6, iteration: 8/20, moves: 11, ncost: 190.72511850708267
# Run: 6, iteration: 9/20, moves: 1, ncost: 190.72506186864916
# Run: 6, iteration: 10/20, moves: 0, ncost: 190.72506186864916
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 1345, ncost: 209.59068760085603
# Run: 7, iteration: 2/20, moves: 334, ncost: 207.2368795302867
# Run: 7, iteration: 3/20, moves: 154, ncost: 206.6394573498721
# Run: 7, iteration: 4/20, moves: 85, ncost: 206.36246467538015
# Run: 7, iteration: 5/20, moves: 63, ncost: 206.20364197325645
# Run: 7, iteration: 6/20, moves: 23, ncost: 206.16243550066093
# Run: 7, iteration: 7/20, moves: 23, ncost: 206.12561827148429
# Run: 7, iteration: 8/20, moves: 13, ncost: 206.11296722972713
# Run: 7, iteration: 9/20, moves: 5, ncost: 206.11107354078874
# Run: 7, iteration: 10/20, moves: 1, ncost: 206.11093189768386
# Run: 7, iteration: 11/20, moves: 5, ncost: 206.1088801951326
# Run: 7, iteration: 12/20, moves: 0, ncost: 206.1088801951326
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1153, ncost: 170.1456418623443
# Run: 8, iteration: 2/20, moves: 283, ncost: 166.13516306417964
# Run: 8, iteration: 3/20, moves: 195, ncost: 161.6228592260439
# Run: 8, iteration: 4/20, moves: 207, ncost: 157.44487801114784
# Run: 8, iteration: 5/20, moves: 128, ncost: 156.29045730146754
# Run: 8, iteration: 6/20, moves: 59, ncost: 155.98701960669916
# Run: 8, iteration: 7/20, moves: 43, ncost: 155.8709500510471
# Run: 8, iteration: 8/20, moves: 17, ncost: 155.83830044094725
# Run: 8, iteration: 9/20, moves: 9, ncost: 155.8275868770475
# Run: 8, iteration: 10/20, moves: 6, ncost: 155.82270732812987
# Run: 8, iteration: 11/20, moves: 3, ncost: 155.820590397118
# Run: 8, iteration: 12/20, moves: 2, ncost: 155.82015223848845
# Run: 8, iteration: 13/20, moves: 0, ncost: 155.82015223848845
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1304, ncost: 193.95252584277435
# Run: 9, iteration: 2/20, moves: 966, ncost: 150.86986838359445
# Run: 9, iteration: 3/20, moves: 160, ncost: 149.64365000125537
# Run: 9, iteration: 4/20, moves: 50, ncost: 149.41477813925252
# Run: 9, iteration: 5/20, moves: 28, ncost: 149.34395703386102
# Run: 9, iteration: 6/20, moves: 9, ncost: 149.32794769205736
# Run: 9, iteration: 7/20, moves: 5, ncost: 149.32000705539636
# Run: 9, iteration: 8/20, moves: 1, ncost: 149.31898541812436
# Run: 9, iteration: 9/20, moves: 0, ncost: 149.31898541812436
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 688, ncost: 201.17364736891585
# Run: 10, iteration: 2/20, moves: 289, ncost: 184.63766312395995
# Run: 10, iteration: 3/20, moves: 400, ncost: 172.7350453885371
# Run: 10, iteration: 4/20, moves: 189, ncost: 170.60282070420632
# Run: 10, iteration: 5/20, moves: 86, ncost: 170.22150949710885
# Run: 10, iteration: 6/20, moves: 42, ncost: 170.12258528229714
# Run: 10, iteration: 7/20, moves: 21, ncost: 170.10593404206435
# Run: 10, iteration: 8/20, moves: 16, ncost: 170.08612496552286
# Run: 10, iteration: 9/20, moves: 14, ncost: 170.0632274819764
# Run: 10, iteration: 10/20, moves: 8, ncost: 170.05594490614138
# Run: 10, iteration: 11/20, moves: 2, ncost: 170.0553080743325
# Run: 10, iteration: 12/20, moves: 0, ncost: 170.0553080743325
# Best run was number 9
# Checking k = 9
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 1139, ncost: 172.23506325558955
# Run: 1, iteration: 2/20, moves: 605, ncost: 164.57638571702404
# Run: 1, iteration: 3/20, moves: 244, ncost: 160.19031802403586
# Run: 1, iteration: 4/20, moves: 189, ncost: 156.53348169547593
# Run: 1, iteration: 5/20, moves: 186, ncost: 152.08197636781608
# Run: 1, iteration: 6/20, moves: 138, ncost: 150.42238336884813
# Run: 1, iteration: 7/20, moves: 77, ncost: 149.9239815515716
# Run: 1, iteration: 8/20, moves: 35, ncost: 149.79184996231464
# Run: 1, iteration: 9/20, moves: 17, ncost: 149.76436154422208
# Run: 1, iteration: 10/20, moves: 11, ncost: 149.73927695637101
# Run: 1, iteration: 11/20, moves: 4, ncost: 149.73550013230698
# Run: 1, iteration: 12/20, moves: 0, ncost: 149.73550013230698
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 1234, ncost: 156.6986374194998
# Run: 2, iteration: 2/20, moves: 221, ncost: 155.45277238577907
# Run: 2, iteration: 3/20, moves: 137, ncost: 154.92652116696237
# Run: 2, iteration: 4/20, moves: 81, ncost: 154.5896330666257
# Run: 2, iteration: 5/20, moves: 76, ncost: 154.0986548519871
# Run: 2, iteration: 6/20, moves: 59, ncost: 153.7368243649091
# Run: 2, iteration: 7/20, moves: 41, ncost: 153.49776265411452
# Run: 2, iteration: 8/20, moves: 30, ncost: 153.3444091409649
# Run: 2, iteration: 9/20, moves: 118, ncost: 143.3106097916047
# Run: 2, iteration: 10/20, moves: 82, ncost: 142.83534403366173
# Run: 2, iteration: 11/20, moves: 13, ncost: 142.8173280730442
# Run: 2, iteration: 12/20, moves: 8, ncost: 142.81060443336497
# Run: 2, iteration: 13/20, moves: 4, ncost: 142.8098743723561
# Run: 2, iteration: 14/20, moves: 0, ncost: 142.8098743723561
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 1278, ncost: 163.50433767638773
# Run: 3, iteration: 2/20, moves: 262, ncost: 160.0398765943961
# Run: 3, iteration: 3/20, moves: 43, ncost: 159.92358412582968
# Run: 3, iteration: 4/20, moves: 15, ncost: 159.90805262577095
# Run: 3, iteration: 5/20, moves: 1, ncost: 159.90779765763185
# Run: 3, iteration: 6/20, moves: 0, ncost: 159.90779765763185
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1292, ncost: 199.54150342218557
# Run: 4, iteration: 2/20, moves: 302, ncost: 196.30259686025607
# Run: 4, iteration: 3/20, moves: 132, ncost: 195.77145539467057
# Run: 4, iteration: 4/20, moves: 97, ncost: 193.53601439775744
# Run: 4, iteration: 5/20, moves: 212, ncost: 183.65162744649933
# Run: 4, iteration: 6/20, moves: 273, ncost: 177.4574379227972
# Run: 4, iteration: 7/20, moves: 144, ncost: 176.41469526985028
# Run: 4, iteration: 8/20, moves: 77, ncost: 176.21332090254003
# Run: 4, iteration: 9/20, moves: 33, ncost: 176.17123056482413
# Run: 4, iteration: 10/20, moves: 16, ncost: 176.15572262552038
# Run: 4, iteration: 11/20, moves: 11, ncost: 176.14239908473672
# Run: 4, iteration: 12/20, moves: 6, ncost: 176.1389728209039
# Run: 4, iteration: 13/20, moves: 0, ncost: 176.1389728209039
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 1058, ncost: 181.862800261573
# Run: 5, iteration: 2/20, moves: 203, ncost: 179.87885799801688
# Run: 5, iteration: 3/20, moves: 108, ncost: 179.12653276950525
# Run: 5, iteration: 4/20, moves: 50, ncost: 178.90003057934413
# Run: 5, iteration: 5/20, moves: 31, ncost: 178.81345256597433
# Run: 5, iteration: 6/20, moves: 18, ncost: 178.78766151993383
# Run: 5, iteration: 7/20, moves: 8, ncost: 178.782367009268
# Run: 5, iteration: 8/20, moves: 0, ncost: 178.782367009268
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 1078, ncost: 190.52273663642424
# Run: 6, iteration: 2/20, moves: 253, ncost: 185.86613316647586
# Run: 6, iteration: 3/20, moves: 214, ncost: 181.45018707191562
# Run: 6, iteration: 4/20, moves: 104, ncost: 180.66302528789936
# Run: 6, iteration: 5/20, moves: 61, ncost: 180.4801337455504
# Run: 6, iteration: 6/20, moves: 14, ncost: 180.45362924724515
# Run: 6, iteration: 7/20, moves: 7, ncost: 180.44139867423027
# Run: 6, iteration: 8/20, moves: 10, ncost: 180.4170921960777
# Run: 6, iteration: 9/20, moves: 11, ncost: 180.3990305753932
# Run: 6, iteration: 10/20, moves: 11, ncost: 180.38906052584082
# Run: 6, iteration: 11/20, moves: 8, ncost: 180.38210330086665
# Run: 6, iteration: 12/20, moves: 6, ncost: 180.37769231709106
# Run: 6, iteration: 13/20, moves: 9, ncost: 180.3674128979458
# Run: 6, iteration: 14/20, moves: 0, ncost: 180.3674128979458
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 1280, ncost: 185.88559682469713
# Run: 7, iteration: 2/20, moves: 493, ncost: 182.40455291057566
# Run: 7, iteration: 3/20, moves: 177, ncost: 181.4092261156698
# Run: 7, iteration: 4/20, moves: 119, ncost: 180.95040381675156
# Run: 7, iteration: 5/20, moves: 54, ncost: 180.84525161512215
# Run: 7, iteration: 6/20, moves: 20, ncost: 180.83348408303635
# Run: 7, iteration: 7/20, moves: 3, ncost: 180.8320501627658
# Run: 7, iteration: 8/20, moves: 0, ncost: 180.8320501627658
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 1213, ncost: 163.90659990483113
# Run: 8, iteration: 2/20, moves: 325, ncost: 158.97599268557633
# Run: 8, iteration: 3/20, moves: 211, ncost: 154.561009486567
# Run: 8, iteration: 4/20, moves: 278, ncost: 149.1597810164989
# Run: 8, iteration: 5/20, moves: 180, ncost: 147.50134379313897
# Run: 8, iteration: 6/20, moves: 108, ncost: 146.9496832960199
# Run: 8, iteration: 7/20, moves: 71, ncost: 146.71326779023406
# Run: 8, iteration: 8/20, moves: 27, ncost: 146.68429627871961
# Run: 8, iteration: 9/20, moves: 12, ncost: 146.67680289993226
# Run: 8, iteration: 10/20, moves: 3, ncost: 146.67518682774758
# Run: 8, iteration: 11/20, moves: 0, ncost: 146.67518682774758
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 1386, ncost: 164.7302621579147
# Run: 9, iteration: 2/20, moves: 510, ncost: 145.35128907305946
# Run: 9, iteration: 3/20, moves: 99, ncost: 144.65891159583518
# Run: 9, iteration: 4/20, moves: 36, ncost: 144.49574525167588
# Run: 9, iteration: 5/20, moves: 25, ncost: 144.40443134391708
# Run: 9, iteration: 6/20, moves: 8, ncost: 144.39480293425646
# Run: 9, iteration: 7/20, moves: 2, ncost: 144.39379008514507
# Run: 9, iteration: 8/20, moves: 0, ncost: 144.39379008514507
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 889, ncost: 172.24692972792693
# Run: 10, iteration: 2/20, moves: 353, ncost: 162.0831061528748
# Run: 10, iteration: 3/20, moves: 96, ncost: 161.77535494976397
# Run: 10, iteration: 4/20, moves: 31, ncost: 161.7348385202435
# Run: 10, iteration: 5/20, moves: 22, ncost: 161.70920985226303
# Run: 10, iteration: 6/20, moves: 13, ncost: 161.69737340667226
# Run: 10, iteration: 7/20, moves: 6, ncost: 161.693134301334
# Run: 10, iteration: 8/20, moves: 2, ncost: 161.69255871401128
# Run: 10, iteration: 9/20, moves: 0, ncost: 161.69255871401128
# Best run was number 2

# %%
# We hope to minimize the cost (i.e. WCSS)
# When k = 3, the elbow curve flattens out significantly.
# Hence, we choose the optimal no. of clustering to be 3.
plt.plot(costs.keys(), costs.values())
plt.scatter(costs.keys(),costs.values())
plt.xlabel("Values of K")
plt.ylabel("Cost (WCSS)")
plt.title("Elbow Curve")
plt.show()

# %% [markdown]
# # (7) Evaluation of the Model
# The model’s performance is evaluated using the **Silhouette Score**. To further assess the quality of the segmentation, we visualize the clustering results in two dimensions using **Factor Analysis of Mixed Data (FAMD)** — a dimensionality reduction technique suitable for datasets containing both categorical and numerical variables. The resulting plot reveals well-defined and distinct cluster structures.

# %%
# We use gower distance to calculate Silhouette Score, due to the presence of categorical data
# !pip install gower

from sklearn.metrics import silhouette_score
import gower
# Out:
# Requirement already satisfied: gower in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from gower) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from gower) (1.16.3)

# %%
# Copy the predictions for k = 3 which we found from the WCSS chart
pred = labels[3]
customers_clustered = df.copy()
customers_clustered['Cluster'] = pred

# Compute the custom distance matrix on the sampled data to be used for calculating the Silhouette Score
# Gower distance is to measure similarity between data points
gower_dist = gower.gower_matrix(customers_clustered.drop(columns=['Cluster']))

# Extract cluster labels for calculating the Silhouette Score
cluster_labels = customers_clustered['Cluster']

# Check the Silhouette Score for k = 3
# A Silhouette Score of 0.43 shows a moderate clustering quality
sil_score = silhouette_score(gower_dist, cluster_labels, metric='precomputed')
print('Silhouette Score: ', sil_score)
# Out:
# Silhouette Score:  0.43433034

# %%
# we use FAMD for reducing the dimensions of mixed data
# !pip install prince
# Out:
# Requirement already satisfied: prince in /usr/local/lib/python3.12/dist-packages (0.16.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from prince) (1.6.1)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from prince) (2.2.2)
# Requirement already satisfied: altair<6.0.0,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from prince) (5.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0.0,>=5.0.0->prince) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0.0,>=5.0.0->prince) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0.0,>=5.0.0->prince) (2.13.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from altair<6.0.0,>=5.0.0->prince) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0.0,>=5.0.0->prince) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->prince) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.5.1->prince) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.5.1->prince) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.5.1->prince) (3.6.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0.0,>=5.0.0->prince) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->prince) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair<6.0.0,>=5.0.0->prince) (3.0.3)

# %%
df_c # dataframe with scaled numerical data and categorical labels
# Out:
#            Age Marital_Status    Income  Tenure_Years  Premium_to_Coverage
# 0     0.353846         Single  0.070396      0.495299             0.307206
# 1     0.492308        Married  0.322489      0.030678             0.171907
# 2     0.230769       Divorced  0.332530      0.121227             0.204700
# 3     0.384615        Married  0.197964      0.090054             0.148853
# 4     0.276923      Separated  0.115423      0.482929             0.220846
# ...        ...            ...       ...           ...                  ...
# 3441  0.369231         Single  0.256746      0.175161             0.165740
# 3442  0.000000       Divorced  0.743434      0.168728             0.193118
# 3443  0.246154       Divorced  0.556521      0.180604             0.177033
# 3444  0.553846        Married  0.365144      0.645225             0.189443
# 3445  0.107692        Widowed  0.331587      0.278575             0.163096
#
# [3446 rows x 5 columns]

# %%
# reduced the dimensionality to 2-D for visualing the clustering
from prince import FAMD

famd = FAMD(n_components=2, random_state=42)
X_famd = famd.fit_transform(df_c)

X_famd #2-D
# Out:
# component         0         1
# 0         -0.279237  0.970623
# 1          0.512036 -0.307947
# 2         -0.055975 -1.068376
# 3          0.053129 -0.155772
# 4          0.155939  0.225473
# ...             ...       ...
# 3441       0.030294 -0.523463
# 3442       0.313372 -2.132985
# 3443       0.685990 -1.411411
# 3444       1.787690  1.221379
# 3445       0.076772 -0.224879
#
# [3446 rows x 2 columns]

# %%
# Add cluster labels to the FAMD result for plotting
X_famd['Cluster'] = pred

# Scatter plot of the 2D data
plt.figure(figsize=(10, 5))
sns.scatterplot(
    data = X_famd,
    x = X_famd.columns[0],
    y = X_famd.columns[1],
    hue ='Cluster',
    palette ='tab10',
    s = 20,
    alpha = 0.6,
)

plt.title("2-D Plot with FAMD")
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
plt.tight_layout()
plt.show()

# %% [markdown]
# # (8) Analysis of the Customer Segments
# After clustering the customers into three distinct segments, we analyze each group’s demographic and policy-related characteristics to better understand their unique profiles. We then use Gemini AI to generate descriptive cluster labels and segment descriptions by providing the summarized metrics of each segment, with the Gemini API key securely stored in Colab’s secret manager.

# %%
customers_clustered
# Out:
#        Age Marital_Status      Income  Tenure_Years  Premium_to_Coverage  \
# 0     41.0         Single   18719.316         11.21             1.236672
# 1     50.0        Married   59456.052          1.82             0.794987
# 2     33.0       Divorced   61078.656          3.65             0.902040
# 3     43.0        Married   39333.528          3.02             0.719727
# 4     36.0      Separated   25995.516         10.96             0.954749
# ...    ...            ...         ...           ...                  ...
# 3441  42.0         Single   48832.356          4.74             0.774854
# 3442  18.0       Divorced  127478.040          4.61             0.864231
# 3443  34.0       Divorced   97274.124          4.85             0.811720
# 3444  54.0        Married   66348.840         14.24             0.852235
# 3445  25.0        Widowed   60926.220          6.83             0.766225
#
#       Cluster
# 0           0
# 1           2
# 2           2
# 3           2
# 4           0
# ...       ...
# 3441        1
# 3442        2
# 3443        2
# 3444        0
# 3445        2
#
# [3446 rows x 6 columns]

# %%
# !pip install -q -U google-genai

# %%
from google.colab import userdata
import google.genai as genai

# Try Colab userdata
try:
    from google.colab import userdata
    api_key = userdata.get('GEMINI_API_KEY')
except Exception:
    # Fallback: use environment variable (GitHub Actions, local)
    api_key = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=api_key) # Create the Gemini client

# %%
# Summarize the features for each cluster
customers_clustered.groupby('Cluster').agg({
    "Age": "mean",
    "Marital_Status": lambda x: x.value_counts().index[0], # mode of marital status
    "Income": "mean",
    "Tenure_Years": "mean",
    "Premium_to_Coverage": "mean",
})
# Out:
#                Age Marital_Status        Income  Tenure_Years  \
# Cluster
# 0        50.215238        Married  59883.644438     13.108858
# 1        26.738707         Single  22475.806389      2.812161
# 2        39.829519       Divorced  95823.932174      3.610837
#
#          Premium_to_Coverage
# Cluster
# 0                   1.352426
# 1                   1.782404
# 2                   0.695017

# %%
# rename the columns
cluster_summary = (
    customers_clustered
    .groupby('Cluster')
    .agg({
        "Age": "mean",
        "Marital_Status": lambda x: x.value_counts().index[0],
        "Income": "mean",
        "Tenure_Years": "mean",
        "Premium_to_Coverage": "mean",
    })
    .rename(columns={
        "Age": "Age_avg",
        "Marital_Status": "Marital_Status_mode",
        "Income": "Income_avg",
        "Tenure_Years": "Tenure_Years_avg",
        "Premium_to_Coverage": "Premium_to_Coverage_avg",
    })
    .reset_index()
)

cluster_summary
# Out:
#    Cluster    Age_avg Marital_Status_mode    Income_avg  Tenure_Years_avg  \
# 0        0  50.215238             Married  59883.644438         13.108858
# 1        1  26.738707              Single  22475.806389          2.812161
# 2        2  39.829519            Divorced  95823.932174          3.610837
#
#    Premium_to_Coverage_avg
# 0                 1.352426
# 1                 1.782404
# 2                 0.695017

# %%
# Due to the randomness of cluster id, sort clusters by Age_avg
cluster_summary_sorted = cluster_summary.sort_values(
    ["Age_avg"], ascending=[True]
).reset_index(drop=True)

# Assign deterministic IDs
cluster_summary_sorted["Cluster_ID"] = range(len(cluster_summary_sorted))
cluster_summary_sorted
# Out:
#    Cluster    Age_avg Marital_Status_mode    Income_avg  Tenure_Years_avg  \
# 0        1  26.738707              Single  22475.806389          2.812161
# 1        2  39.829519            Divorced  95823.932174          3.610837
# 2        0  50.215238             Married  59883.644438         13.108858
#
#    Premium_to_Coverage_avg  Cluster_ID
# 0                 1.782404           0
# 1                 0.695017           1
# 2                 1.352426           2

# %%
# Create mapping rule for converting old cluster IDs to new ones
id_map = dict(
    zip(cluster_summary_sorted["Cluster"], cluster_summary_sorted["Cluster_ID"])
)

id_map
# Out:
# {1: 0, 2: 1, 0: 2}

# %%
# Drop the old cluster ID, replaced by new cluster ID based on the average age
cluster_summary_sorted = cluster_summary_sorted.drop(['Cluster'], axis=1)
cluster_summary_sorted
# Out:
#      Age_avg Marital_Status_mode    Income_avg  Tenure_Years_avg  \
# 0  26.738707              Single  22475.806389          2.812161
# 1  39.829519            Divorced  95823.932174          3.610837
# 2  50.215238             Married  59883.644438         13.108858
#
#    Premium_to_Coverage_avg  Cluster_ID
# 0                 1.782404           0
# 1                 0.695017           1
# 2                 1.352426           2

# %%
# Apply mapping rule to convert old cluster IDs to new IDs in the customer dataset
customers_clustered["Cluster_ID"] = customers_clustered["Cluster"].map(id_map)

customers_clustered = customers_clustered.drop(columns=['Cluster'])

customers_clustered
# Out:
#        Age Marital_Status      Income  Tenure_Years  Premium_to_Coverage  \
# 0     41.0         Single   18719.316         11.21             1.236672
# 1     50.0        Married   59456.052          1.82             0.794987
# 2     33.0       Divorced   61078.656          3.65             0.902040
# 3     43.0        Married   39333.528          3.02             0.719727
# 4     36.0      Separated   25995.516         10.96             0.954749
# ...    ...            ...         ...           ...                  ...
# 3441  42.0         Single   48832.356          4.74             0.774854
# 3442  18.0       Divorced  127478.040          4.61             0.864231
# 3443  34.0       Divorced   97274.124          4.85             0.811720
# 3444  54.0        Married   66348.840         14.24             0.852235
# 3445  25.0        Widowed   60926.220          6.83             0.766225
#
#       Cluster_ID
# 0              2
# 1              1
# 2              1
# 3              1
# 4              2
# ...          ...
# 3441           0
# 3442           1
# 3443           1
# 3444           2
# 3445           1
#
# [3446 rows x 6 columns]

# %%
# Function for asking Gemini for the cluster names and descriptions
import json
import re

def get_cluster_labels_from_gemini(summary_df):
    # Turn the cluster summary into a list of dicts
    data = summary_df.to_dict(orient="records")

    prompt = f"""
You are a marketing analyst for an insurance company.

You will receive a list of customer clusters with summary statistics.
Each record has:
- Cluster: internal numeric ID
- Age_avg
- Marital_Status_mode
- Income_avg
- Tenure_Years_avg
- Premium_to_Coverage_avg

Task:
1. For each cluster, create:
   - name: a short, catchy 2–4 word segment name
   - description: one concise sentence explaining the segment (max 25 words)

2. Respond ONLY with valid JSON in this exact format:

{{
  "0": {{
    "cluster_name": "Segment Name",
    "description": "Short sentence..."
  }},
  "1": {{
    "cluster_name": "Another Name",
    "description": "Short sentence..."
  }}
}}

Here is the cluster data (as JSON):
{json.dumps(data, indent=2)}
"""

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )

    text = response.text.strip()

    # Strip code fences if Gemini wraps the JSON in ```json ... ```
    text = re.sub(r"^```json", "", text, flags=re.IGNORECASE).strip()
    text = re.sub(r"^```", "", text).strip()
    text = re.sub(r"```$", "", text).strip()

    labels_json = json.loads(text)
    return labels_json

# %%
# Feeding the summarized data of each segment into Gemini
RUN_GENAI = True

if RUN_GENAI:
  print("Running Gen-AI labeling...")
  labels_json = get_cluster_labels_from_gemini(cluster_summary_sorted)
else:
    print("Skipping Gen-AI — using saved labels from BigQuery.")

labels_json
# Out:
# Running Gen-AI labeling...
# {'0': {'cluster_name': 'Young Urban Starters',
#   'description': 'Young, single, budget-conscious customers new to insurance, typically with lower income and shorter tenure.'},
#  '1': {'cluster_name': 'Discerning Independents',
#   'description': 'Middle-aged, divorced, high-income individuals with very efficient premium-to-coverage ratios, indicating savvy and discerning insurance buyers.'},
#  '2': {'cluster_name': 'Loyal Family Households',
#   'description': 'Mature, married, upper-middle-income individuals with long tenure, representing loyal customers with established family insurance needs.'}}

# %%
# Summary of the cluster names and their descriptions
df_labels = pd.DataFrame.from_dict(labels_json, orient='index').reset_index()
df_labels = df_labels.rename(columns={'index': 'cluster_id'})
df_labels
# Out:
#   cluster_id             cluster_name  \
# 0          0     Young Urban Starters
# 1          1  Discerning Independents
# 2          2  Loyal Family Households
#
#                                          description
# 0  Young, single, budget-conscious customers new ...
# 1  Middle-aged, divorced, high-income individuals...
# 2  Mature, married, upper-middle-income individua...

# %%
# Map cluster name and descriptions to the customer table
cluster_name_map = {int(k): v["cluster_name"] for k, v in labels_json.items()}
cluster_desc_map = {int(k): v["description"] for k, v in labels_json.items()}

customers_clustered["Cluster_Label"] = customers_clustered["Cluster_ID"].map(cluster_name_map)
customers_clustered["Cluster_Des"] = customers_clustered["Cluster_ID"].map(cluster_desc_map)

# %%
customers_clustered
# Out:
#        Age Marital_Status      Income  Tenure_Years  Premium_to_Coverage  \
# 0     41.0         Single   18719.316         11.21             1.236672
# 1     50.0        Married   59456.052          1.82             0.794987
# 2     33.0       Divorced   61078.656          3.65             0.902040
# 3     43.0        Married   39333.528          3.02             0.719727
# 4     36.0      Separated   25995.516         10.96             0.954749
# ...    ...            ...         ...           ...                  ...
# 3441  42.0         Single   48832.356          4.74             0.774854
# 3442  18.0       Divorced  127478.040          4.61             0.864231
# 3443  34.0       Divorced   97274.124          4.85             0.811720
# 3444  54.0        Married   66348.840         14.24             0.852235
# 3445  25.0        Widowed   60926.220          6.83             0.766225
#
#       Cluster_ID            Cluster_Label  \
# 0              2  Loyal Family Households
# 1              1  Discerning Independents
# 2              1  Discerning Independents
# 3              1  Discerning Independents
# 4              2  Loyal Family Households
# ...          ...                      ...
# 3441           0     Young Urban Starters
# 3442           1  Discerning Independents
# 3443           1  Discerning Independents
# 3444           2  Loyal Family Households
# 3445           1  Discerning Independents
#
#                                             Cluster_Des
# 0     Mature, married, upper-middle-income individua...
# 1     Middle-aged, divorced, high-income individuals...
# 2     Middle-aged, divorced, high-income individuals...
# 3     Middle-aged, divorced, high-income individuals...
# 4     Mature, married, upper-middle-income individua...
# ...                                                 ...
# 3441  Young, single, budget-conscious customers new ...
# 3442  Middle-aged, divorced, high-income individuals...
# 3443  Middle-aged, divorced, high-income individuals...
# 3444  Mature, married, upper-middle-income individua...
# 3445  Middle-aged, divorced, high-income individuals...
#
# [3446 rows x 8 columns]

# %%
# Show the proportion of customer in each segment
plt.figure(figsize=(8, 5))
value_counts = customers_clustered.iloc[:, -2].value_counts() # Counts how many customers belong to each cluster label
plt.pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%',
        colors=sns.color_palette("pastel"), startangle=140)
plt.title("Proportion of Customers in Each Segment")
plt.show()

# Analyze the distribution of categorical features in each segment
for feature in categorical_cols:
    df_i = customers_clustered[[feature, 'Cluster_Label']].groupby(['Cluster_Label'])

    # Create consistent color map per feature
    categories = customers_clustered[feature].unique()
    palette = sns.color_palette("pastel", len(categories))
    color_map = dict(zip(categories, palette))

    # Create a new figure of subplots for each feature
    plt.figure(figsize=(18, 5))
    j = 1 # counter for the position of each subplot

    # Make a subplot for the feature distribution for each cluster
    for cluster in customers_clustered.Cluster_Label.unique():
      # Count the number of every unique items of a feature of a selected cluster
        df_c = df_i.get_group((cluster,))[feature] # extract one feature column for a selected cluster
        value_counts = df_c.value_counts() # count the number of every unique items within that feature
        # set the colours of the features
        colors = [color_map[val] for val in value_counts.index]

        plt.subplot(1, 3, j) # show 3 subplots in every row
        plt.pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%',
                colors=colors, startangle=140)
        plt.title(f"{feature} in {cluster}")
        # move the counter by 1 for preparing making another subplot for the next cluster
        j = j + 1

    plt.suptitle(f"Distribution of {feature} Across Clusters", fontsize=16)
    plt.tight_layout()
    plt.show()


# Boxplot for numerical features
plt.figure(figsize=(14, 8))
j = 1 # counter for the position of subplot

for feature in numerical_cols:
    # Boxplot for numerical variable per cluster
    plt.subplot(2, 2, j)
    sns.boxplot(x = 'Cluster_Label', y = feature, data = customers_clustered)
    plt.title(f"Distribution of {feature} per Segment")
    j = j + 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # (9) Load the Datasets to Google BigQuery
# Finally, the updated customers, products, and sales tables are written directly to *Google BigQuery*, where the process is automated to run daily via a *GitHub Action* workflow.

# %%
# Connect pandas to Google BigQuery
# !pip install --upgrade pandas-gbq google-auth
# Out:
# Requirement already satisfied: pandas-gbq in /usr/local/lib/python3.12/dist-packages (0.31.1)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (2.43.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (75.2.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (1.4.4)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (2.0.2)
# Requirement already satisfied: pandas<3.0.0,>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (2.2.2)
# Requirement already satisfied: pyarrow>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (18.1.0)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (1.9.1)
# Requirement already satisfied: psutil>=5.9.8 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (7.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (1.2.2)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.20.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (3.38.0)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from pandas-gbq) (25.0)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth) (4.9.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.32.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq) (2.0.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.8.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=1.1.4->pandas-gbq) (2025.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.71.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->pandas-gbq) (2025.11.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq) (3.3.1)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.20.0->pandas-gbq) (4.15.0)

# %%
# Complete customer table with the sorted cluster ID
df_clustered_customers = pd.concat([df_customers, customers_clustered['Cluster_ID']], axis=1) # concatenate the columns of cluster number to the original dataset

df_clustered_customers
# Out:
#      Customer_ID  Age  Gender                City Marital_Status  \
# 0        HL00001   41    Male           Sheffield         Single
# 1        HL00002   50  Female          Manchester        Married
# 2        HL00003   33  Female              London       Divorced
# 3        HL00004   43    Male           Edinburgh        Married
# 4        HL00005   36    Male           Liverpool      Separated
# ...          ...  ...     ...                 ...            ...
# 3441     HL03442   42    Male             Bristol         Single
# 3442     HL03443   18    Male               Leeds       Divorced
# 3443     HL03444   34  Female              London       Divorced
# 3444     HL03445   54  Female             Belfast        Married
# 3445     HL03446   25  Female  Kingston upon Hull        Widowed
#
#               Education    Occupation      Income Preferred_Language  \
# 0      Associate Degree        Lawyer   18719.316             French
# 1             Doctorate  Entrepreneur   59456.052            English
# 2             Doctorate        Lawyer   61078.656             Arabic
# 3       Master's Degree        Lawyer   39333.528            English
# 4     Bachelor's Degree         Nurse   25995.516            English
# ...                 ...           ...         ...                ...
# 3441    Master's Degree       Manager   48832.356            English
# 3442   Associate Degree        Doctor  127478.040            English
# 3443          Doctorate  Entrepreneur   97274.124            Chinese
# 3444  Bachelor's Degree       Manager   66348.840            English
# 3445  Bachelor's Degree       Manager   60926.220            English
#
#       Preferred_Channel Preferred_Time  Cluster_ID
# 0                 Email      Afternoon           2
# 1                 Email      Afternoon           1
# 2                 Email        Morning           1
# 3                 Email        Evening           1
# 4                  Mail        Evening           2
# ...                 ...            ...         ...
# 3441              Email        Anytime           0
# 3442              Email      Afternoon           1
# 3443  In-Person Meeting        Morning           1
# 3444              Phone        Anytime           2
# 3445              Email        Morning           1
#
# [3446 rows x 12 columns]

# %%
df_sales
# Out:
#      Policy_ID Customer_ID Product_ID Purchase_Date      Premium  \
# 0      P000008     HL00008  POL200008    2022-05-04   861.832800
# 1      P000010     HL00010  POL200016    2022-03-17  1294.144416
# 2      P000015     HL00015  POL200017    2022-05-19  2470.369199
# 3      P000019     HL00019  POL200018    2022-08-03  2032.112144
# 4      P000022     HL00022  POL200015    2023-05-24  1156.180369
# ...        ...         ...        ...           ...          ...
# 3459   P003458     HL03367  POL200009    2022-01-22  5375.637343
# 3460   P003459     HL03367  POL200001    2021-09-16  4798.328801
# 3461   P003462     HL00347  POL200001    2011-06-26  5465.828597
# 3462   P003463     HL00347  POL200016    2012-06-11  5015.488343
# 3463   P003464     HL00347  POL200015    2013-07-02  4713.002623
#
#           Coverage  Tenure_Years  Premium_to_Coverage
# 0      97928.79508          3.62             0.880061
# 1     100724.49880          3.75             1.284836
# 2     102937.51920          3.58             2.399872
# 3      98439.34626          3.37             2.064329
# 4     101259.37510          2.56             1.141801
# ...            ...           ...                  ...
# 3459  519777.85190          3.90             1.034218
# 3460  336051.20600          4.25             1.427856
# 3461  382502.92070         14.48             1.428964
# 3462  396869.88540         13.52             1.263761
# 3463  389222.51350         12.46             1.210876
#
# [3464 rows x 8 columns]

# %%
df_products
# Out:
#    Product_ID           Product_Name Product_Type    Category
# 0   POL200000        WellBeing Cover       Health       Group
# 1   POL200001             MediAssist       Health       Group
# 2   POL200002        FamilyLife Plus         Life       Group
# 3   POL200003             LifeShield         Life       Group
# 4   POL200004           SecureLegacy         Life       Group
# 5   POL200005              DriveSure         Auto       Group
# 6   POL200006            TradeSecure     Property    Business
# 7   POL200007            AssetShield     Property    Business
# 8   POL200008          OfficeProtect     Property    Business
# 9   POL200009            MotorShield         Auto    Business
# 10  POL200010            TruePromise         Life  Individual
# 11  POL200011           HealthBridge       Health  Individual
# 12  POL200012            PrimeHealth       Health  Individual
# 13  POL200013         EverGuard Life         Life  Individual
# 14  POL200014        QuickCover Auto         Auto  Individual
# 15  POL200015       VitalCare Family       Health      Family
# 16  POL200016     TruePromise Family         Life      Family
# 17  POL200017      LifeShield Family         Life      Family
# 18  POL200018  SuperGold Life Family         Life      Family

# %%
X_famd # the cluster is based on the previous unsorted cluster id
# Out:
# component         0         1  Cluster
# 0         -0.279237  0.970623        0
# 1          0.512036 -0.307947        2
# 2         -0.055975 -1.068376        2
# 3          0.053129 -0.155772        2
# 4          0.155939  0.225473        0
# ...             ...       ...      ...
# 3441       0.030294 -0.523463        1
# 3442       0.313372 -2.132985        2
# 3443       0.685990 -1.411411        2
# 3444       1.787690  1.221379        0
# 3445       0.076772 -0.224879        2
#
# [3446 rows x 3 columns]

# %%
# Map the old cluster ID to sorted cluster ID in X_famd
X_famd['Cluster_ID'] = X_famd['Cluster'].map(id_map)
X_famd = X_famd.drop(['Cluster'], axis = 1)

X_famd # based on the sorted new cluster_id
# Out:
# component         0         1  Cluster_ID
# 0         -0.279237  0.970623           2
# 1          0.512036 -0.307947           1
# 2         -0.055975 -1.068376           1
# 3          0.053129 -0.155772           1
# 4          0.155939  0.225473           2
# ...             ...       ...         ...
# 3441       0.030294 -0.523463           0
# 3442       0.313372 -2.132985           1
# 3443       0.685990 -1.411411           1
# 3444       1.787690  1.221379           2
# 3445       0.076772 -0.224879           1
#
# [3446 rows x 3 columns]

# %%
X_famd["Cluster_ID"] = X_famd["Cluster_ID"].astype(int) # convert to string for table merge
df_labels["cluster_id"] = df_labels["cluster_id"].astype(int) # convert to string for table merge

famd_chart = X_famd.merge(
    df_labels,
    how="left",
    left_on="Cluster_ID",
    right_on="cluster_id"
)

famd_chart = famd_chart.drop(['cluster_id'], axis = 1)

# %%
famd_chart
# Out:
#              0         1  Cluster_ID             cluster_name  \
# 0    -0.279237  0.970623           2  Loyal Family Households
# 1     0.512036 -0.307947           1  Discerning Independents
# 2    -0.055975 -1.068376           1  Discerning Independents
# 3     0.053129 -0.155772           1  Discerning Independents
# 4     0.155939  0.225473           2  Loyal Family Households
# ...        ...       ...         ...                      ...
# 3441  0.030294 -0.523463           0     Young Urban Starters
# 3442  0.313372 -2.132985           1  Discerning Independents
# 3443  0.685990 -1.411411           1  Discerning Independents
# 3444  1.787690  1.221379           2  Loyal Family Households
# 3445  0.076772 -0.224879           1  Discerning Independents
#
#                                             description
# 0     Mature, married, upper-middle-income individua...
# 1     Middle-aged, divorced, high-income individuals...
# 2     Middle-aged, divorced, high-income individuals...
# 3     Middle-aged, divorced, high-income individuals...
# 4     Mature, married, upper-middle-income individua...
# ...                                                 ...
# 3441  Young, single, budget-conscious customers new ...
# 3442  Middle-aged, divorced, high-income individuals...
# 3443  Middle-aged, divorced, high-income individuals...
# 3444  Mature, married, upper-middle-income individua...
# 3445  Middle-aged, divorced, high-income individuals...
#
# [3446 rows x 5 columns]

# %%
# converts all column names to strings
famd_chart.columns = famd_chart.columns.map(str)
famd_chart
# Out:
#              0         1  Cluster_ID             cluster_name  \
# 0    -0.279237  0.970623           2  Loyal Family Households
# 1     0.512036 -0.307947           1  Discerning Independents
# 2    -0.055975 -1.068376           1  Discerning Independents
# 3     0.053129 -0.155772           1  Discerning Independents
# 4     0.155939  0.225473           2  Loyal Family Households
# ...        ...       ...         ...                      ...
# 3441  0.030294 -0.523463           0     Young Urban Starters
# 3442  0.313372 -2.132985           1  Discerning Independents
# 3443  0.685990 -1.411411           1  Discerning Independents
# 3444  1.787690  1.221379           2  Loyal Family Households
# 3445  0.076772 -0.224879           1  Discerning Independents
#
#                                             description
# 0     Mature, married, upper-middle-income individua...
# 1     Middle-aged, divorced, high-income individuals...
# 2     Middle-aged, divorced, high-income individuals...
# 3     Middle-aged, divorced, high-income individuals...
# 4     Mature, married, upper-middle-income individua...
# ...                                                 ...
# 3441  Young, single, budget-conscious customers new ...
# 3442  Middle-aged, divorced, high-income individuals...
# 3443  Middle-aged, divorced, high-income individuals...
# 3444  Mature, married, upper-middle-income individua...
# 3445  Middle-aged, divorced, high-income individuals...
#
# [3446 rows x 5 columns]

# %%
# Import the to_gbq() function from the pandas_gbq package to write
# panda dataframe to Google BigQuery tables
from pandas_gbq import to_gbq

# Write the customer dataset to BigQuery
to_gbq(
    df_clustered_customers,
    destination_table='portfolio.customers',
    project_id='new-project-456705',
    if_exists='replace'
)

# Write the sales dataset to BigQuery
to_gbq(
    df_sales,
    destination_table='portfolio.sales',
    project_id='new-project-456705',
    if_exists='replace'
)

# Write the products dataset to BigQuery
to_gbq(
    df_products,
    destination_table='portfolio.products',
    project_id='new-project-456705',
    if_exists='replace'
)

# Write the data of the 2-D clustering plot to Bigqery
to_gbq(
    famd_chart,
    destination_table='portfolio.scatter_chart',
    project_id='new-project-456705',
    if_exists='replace'
)

# Write the data of the cluster labels table to Bigqery
to_gbq(
    df_labels,
    destination_table='portfolio.df_labels',
    project_id='new-project-456705',
    if_exists='replace'
)

# Write the data of the cluster summary to Bigqery
to_gbq(
    cluster_summary_sorted,
    destination_table='portfolio.cluster_summary_sorted',
    project_id='new-project-456705',
    if_exists='replace'
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 10810.06it/s]
# 100%|██████████| 1/1 [00:00<00:00, 9986.44it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11781.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 9915.61it/s]
# 100%|██████████| 1/1 [00:00<00:00, 8630.26it/s]
# 100%|██████████| 1/1 [00:00<00:00, 12446.01it/s]
